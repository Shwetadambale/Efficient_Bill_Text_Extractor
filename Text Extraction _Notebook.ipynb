# %%
pip install paddlepaddle paddleocr
# Out:
# ...
#
# ...

# %%
import paddleocr
from paddleocr import PaddleOCR

# %%
pip install paddlepaddle paddleocr --upgrade
# Out:
# ...
#
# ...

# %%
from paddleocr import PaddleOCR

ocr = PaddleOCR(lang='en')
# Out:
# [2023/06/28 14:56:16] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\rec\\en\\en_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25
# ...

# %%
from paddleocr import PaddleOCR

# Declare the PaddleOCR class
ocr = PaddleOCR()

img_path ="C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice1.jpeg"


# Perform prediction
result = ocr.ocr(img_path, rec=False)
print(result)
# Out:
# [2023/06/28 15:01:48] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25
# ...

# %%
[
  [[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
  [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
  [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
  [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
  [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
  [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
  [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]
]
# Out:
# [[[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
#   [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
#   [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
#   [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
#   [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
#   [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
#   [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]]

# %%
import cv2
import numpy as np

# read image using opencv python
image = cv2.imread("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice1.jpeg")

for row in result[0]:
    # conver float to integer
    row = [[int(r[0]), int(r[1])] for r in row]
    # Draw polyline on image
    cv2.polylines(image, [np.array(row)], True, (255, 0, 0), 1)

cv2.imwrite("out.jpg", image)
# Out:
# True

# %%
result = ocr.ocr("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice1.jpeg")
print (result)
# Out:
# [2023/06/28 15:09:57] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/06/28 15:09:58] ppocr DEBUG: dt_boxes num : 67, elapse : 0.5702028274536133
# [2023/06/28 15:10:08] ppocr DEBUG: rec_res num  : 67, elapse : 10.659779787063599
# ...

# %%
concat_output = "\n".join(row[1][0] for row in result[0])
print(concat_output)
# Out:
# TAX INVOIC
# AVENUE SUPERMARTS LTD
# Invoice No.
# CIN：L51900MH2000PLC126473
# Invoice Date
# GSTIN：36AACCA8432H1ZR
# FSSAI No:13620011000658
# SHIPTO
# TRIDDYSIN
# DMART HIMAYATHNAGAR
# H.NO.3-6-288/4$5
# OPP OID MLA QUARTERS
# BESIDE TOYATA SHOWROOM
# HYDERGUDA BASHERBAGH ROAD
# MRP
# RA
# HYDERABAD 500029
# 243
# 187
# Phone:040-23298560
# TAX INVOICE
# Bi11 No :501802014-012959
# Bi11 Dt:03/02/2023 V&u.:S138014-0242
# Cashier:ANT/138322
# n1me-:12:55PM
# HSN
# Particular Qty/Kg Rate
# Value
# T
# 1CGST@ 0.00% SGST@0.00%
# 250100AASHIR-1kg
# 2
# 26.32
# 52. 64
# 2 CGST@ 9.00% SGST@
# 9.00%
# 330499NIVE-400m
# 000
# 510.00
# Items:
# 2 Qty:
# Amt
# 562.64
# <-- GST Breakup
# (Amount INR)
# GSTTaxable
# SGST
# CESS
# Total
# IND Amount
# Amount
# 52.64
# 52.64
# 2
# 432.20
# 38.9038.90
# 510.00
# 484.8438.9038.90
# 562.64
# T
# <-- Amount Recd From Customer -->
# 562.64

# %%
# Declare the PaddleOCR class
ocr = PaddleOCR()

img_path = "C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice2.jpeg"

# Perform prediction
result = ocr.ocr(img_path, rec=False)
print(result)
# Out:
# [2023/06/28 15:15:31] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25
# ...

# %%
 [
    [[[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]], ('Introducing Affiliate Template for Webflow', 0.9333747029304504)],
    [[[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]], ('Easy-to-use Template', 0.9670184850692749)],
    [[[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]], ('for building Affiliate', 0.9301523566246033)],
    [[[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]], ('Sites', 0.9647798538208008)],
    [[[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]], ('Affiliate is a Webflow template made for entrepreneurs whc', 0.9189010858535767)],
    [[[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]], ('Want a professional and polished site ready to start and', 0.9063881039619446)],
    [[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]], ('grow their affiliate marketing business in any niche', 0.9410164952278137)]
  ]
# Out:
# [[[[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]],
#   ('Introducing Affiliate Template for Webflow', 0.9333747029304504)],
#  [[[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
#   ('Easy-to-use Template', 0.9670184850692749)],
#  [[[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
#   ('for building Affiliate', 0.9301523566246033)],
#  [[[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
#   ('Sites', 0.9647798538208008)],
#  [[[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
#   ('Affiliate is a Webflow template made for entrepreneurs whc',
#    0.9189010858535767)],
#  [[[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
#   ('Want a professional and polished site ready to start and',
#    0.9063881039619446)],
#  [[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
#   ('grow their affiliate marketing business in any niche',
#    0.9410164952278137)]]

# %%
import cv2
import numpy as np

# read image using opencv python
image = cv2.imread("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice2.jpeg")

for row in result[0]:
    # conver float to integer
    row = [[int(r[0]), int(r[1])] for r in row]
    # Draw polyline on image
    cv2.polylines(image, [np.array(row)], True, (255, 0, 0), 1)

cv2.imwrite("out.jpg", image)
# Out:
# True

# %%
result = ocr.ocr("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice2.jpeg")
print(result)
# Out:
# [2023/06/28 15:18:36] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/06/28 15:18:37] ppocr DEBUG: dt_boxes num : 55, elapse : 0.5793476104736328
# [2023/06/28 15:18:46] ppocr DEBUG: rec_res num  : 55, elapse : 9.43423318862915
# ...

# %%
concat_output = "\n".join(row[1][0] for row in result[0])
print(concat_output)
# Out:
# AVENUE SUPERMARTS LTD
# CIN NO :L51900MH2000PLC126473
# GSTIN：36AACCA8432H1ZR
# FSSAI No:13620011000658
# DMART HIMAYATHNAGAR
# H.NO.3-6-288/4$5
# OPP OID MLA QUARTERS
# BESIDE TOYATA SHOWROOM
# HYDERGUDA BASHERBAGH ROAD
# HYDERABAD500029
# Phone:040-23298560
# TAX INVOICE
# B111No:501803014-017065
# Bi11 Dt:06/03/2023 Vou.:S138014-0568
# Cashier:MVS/138433
# -Time :7:16PM
# HSN
# Particuiar Qty/Kg
# Value
# 1CGST@6.00%SGST@6.00%
# 170490 GULA-100g
# 2
# 15
# 30.00
# 2 CGSTQ 9.00% SGSTQ 9.00%
# 190590L0TTE-336g
# 1
# 105
# 105.00
# 340220 RIN-800ml
# 4
# 146.00
# 584.00
# Items:
# 3Qty:
# Amt
# 19.00
# GST Breakup Detaiis
# (Amount
# NR)
# GST TaxableCGST
# SGST
# CESS
# Total
# IND Amount
# Amount
# 26.78
# 1.61161
# 30.00
# 2
# 583.90
# 52.5552.55
# 689.00
# 610.6854.1654.16
# 719.00

# %%
# Declare the PaddleOCR class
ocr = PaddleOCR()

img_path = "C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice3.jpeg"

# Perform prediction
result = ocr.ocr(img_path, rec=False)
print(result)
# Out:
# [2023/06/28 15:21:03] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25
# ...

# %%
 [
  [[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
  [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
  [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
  [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
  [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
  [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
  [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]
]
# Out:
# [[[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
#   [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
#   [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
#   [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
#   [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
#   [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
#   [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]]

# %%
import cv2
import numpy as np

# read image using opencv python
image = cv2.imread("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice3.jpeg"
)

for row in result[0]:
    # conver float to integer
    row = [[int(r[0]), int(r[1])] for r in row]
    # Draw polyline on image
    cv2.polylines(image, [np.array(row)], True, (255, 0, 0), 1)

cv2.imwrite("out.jpg", image)
# Out:
# True

# %%
result = ocr.ocr("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice3.jpeg"
)
print(result)
# Out:
# [2023/06/28 15:23:35] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/06/28 15:23:36] ppocr DEBUG: dt_boxes num : 106, elapse : 0.5577774047851562
# [2023/06/28 15:23:51] ppocr DEBUG: rec_res num  : 106, elapse : 15.681311845779419
# ...

# %%
concat_output = "\n".join(row[1][0] for row in result[0])
print(concat_output)
# Out:
# e
# S
# DUB
# DMart
# AVENUE SUPERMARTS LTD
# CIN No : L51900MH2000PLC126473
# GSTIN36AACCA8432H1ZR
# FSSAI No :13620011000658
# DMART SHEKHPETH
# B-1-299/5,
# Duties Bullding,Al-Hamra Colony,
# Shalkpet Tolchowki,Hyd-500008
# Phone:
# 7207851378175
# TAX INVOICE
# Bill Dt
# 04/04/2023
# 9:49P1)
# B11lNo501904020-000797
# Cashier
# QL/108569
# Vou.No:S108020-0227
# Qty/K
# N/Rate
# Particulars
# Value
# HSN
# 1)CGST@2.50%,SGST@2
# 150810 ASGRAND DFILT-11t
# 177.00
# 354.00
# 151219FREEDOMSUNFL(W-51t
# 2
# 660.00
# 1320.00
# 190240 BAMBINO VERMI-1.4kg
# 3
# 107.00
# 321.00
# 2)CGST@6.00%，SGSF@6.00%
# 1
# 17.00
# 17.00
# 300490 HAPPYDENT WHITE
# 3)CGST@9.00%，5T@9.00%
# 330710 GILLETE FOAM F1Bg
# 1
# 230.00
# 230.00
# 330720 KS SPARK DE020ml
# 1
# 180.00
# 180.00
# 4)CGST@2.50%SGST电2.50%
# 151550 ANURAG DEEPARAD-11t
# 2
# 125.00
# 250.00
# Qty:
# 12
# 2672.00
# Items:
# Breakup Detalls
# >(Amount INR)
# CST
# Taxable
# CGST
# SGST
# CESS
# Total
# GST
# ND
# Armiount
# Amaunt
# 1900.00
# ...

# %%
# Declare the PaddleOCR class
ocr = PaddleOCR()
img_path = "C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice4.jpeg"


# Perform prediction
result = ocr.ocr(img_path, rec=False)
print(result)
# Out:
# [2023/06/28 15:26:34] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25
# ...

# %%
[
  [[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
  [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
  [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
  [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
  [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
  [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
  [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]
]
# Out:
# [[[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
#   [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
#   [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
#   [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
#   [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
#   [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
#   [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]]

# %%
import cv2
import numpy as np

# read image using opencv python
img_path = "C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice5.jpeg"

for row in result[0]:
    # conver float to integer
    row = [[int(r[0]), int(r[1])] for r in row]
    # Draw polyline on image
    cv2.polylines(image, [np.array(row)], True, (255, 0, 0), 1)

cv2.imwrite("out.jpg", image)
# Out:
# True

# %%
result = ocr.ocr("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice5.jpeg")
print(result)
# Out:
# [2023/06/28 15:30:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/06/28 15:30:08] ppocr DEBUG: dt_boxes num : 53, elapse : 0.48166584968566895
# [2023/06/28 15:30:18] ppocr DEBUG: rec_res num  : 53, elapse : 9.640887022018433
# ...

# %%
concat_output = "\n".join(row[1][0] for row in result[0])
print(concat_output)
# Out:
# D"Mart
# CIN:L51900MH2000PLC126473
# GSTIN:36AACCA8432H1ZR
# FSSAI No :1362001500023B
# Upperpally(Attapura)
# NEAR PILLAR NO.198
# UPPERPALLY
# RAJENDRANAGARNER
# HYDERABA0 50004B
# AXINVOICE
# B111 No :502502012-002653 B111Dt :13/02/20233:48P
# Vou.No:S151012-0067
# Cashler : NAB/151573
# HSN
# Particulars
# Qty/ng
# N/Rate
# Value
# 1) CGST @9.00%,SGST @9.00%
# 340250 SURF EXCEL MATI-21t
# 2
# 399.00
# 798.00
# Items:1
# Qty
# 2
# 8.00
# Gsr Breakup Details
# (Amount Inn)
# GST
# Taxable
# CGST
# SGST
# CESS
# Total
# IND
# Arnaunt
# Amount
# 1
# 676.28
# 60.86
# 60.86
# 798.00
# Amount Recetyeu From Customer
# Card Payment :
# 798.00-3
# **Saved Rs.162.00/-UnMRP**

# %%
# Declare the PaddleOCR class
ocr = PaddleOCR()

img_path = "C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice6.jpeg"


# Perform prediction
result = ocr.ocr(img_path, rec=False)
print(result)
# Out:
# [2023/06/28 15:32:49] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25
# ...

# %%
[
  [[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
  [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
  [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
  [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
  [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
  [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
  [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]
]
# Out:
# [[[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
#   [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
#   [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
#   [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
#   [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
#   [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
#   [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]]

# %%
import cv2
import numpy as np

# read image using opencv python
image = cv2.imread("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice6.jpeg")

for row in result[0]:
    # conver float to integer
    row = [[int(r[0]), int(r[1])] for r in row]
    # Draw polyline on image
    cv2.polylines(image, [np.array(row)], True, (255, 0, 0), 1)

# %%
result = ocr.ocr("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice6.jpeg")
print(result)
# Out:
# [2023/06/28 15:35:19] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/06/28 15:35:19] ppocr DEBUG: dt_boxes num : 61, elapse : 0.5632891654968262
# [2023/06/28 15:35:29] ppocr DEBUG: rec_res num  : 61, elapse : 9.43047547340393
# ...

# %%
concat_output = "\n".join(row[1][0] for row in result[0])
print(concat_output)
# Out:
# D"Mart
# AVENUE SUPERMARTS LTD
# CIN No ：L51900MH2000PLC126473
# GSTIN:36AACCA8432H1ZR
# FSSAI No :13620013000657
# DMART KAVURI HILLS
# PLOTNO:43/P.45.46848
# KAVURI HILLS ROAD MADHAPUR
# HYDERABAD-500081
# Phone:040-23119921
# TAX INVOICE
# Br1l No:502003017-004782B
# B111DE：06/03/2023(12:47PM
# You. No :S103017-0016
# CashMer : RAJ/103450
# NSN
# Particulars
# Qty/kg
# N/Rate
# Value
# CGST@2.50%,SGST 2.50%
# 150890 FREE0DM GROUNDN-11t
# 5
# 178.00
# 890.00
# 190410 KURMUR-500g
# 1
# 45.50
# 45.50
# Items: 2
# Qty:
# 6
# 935.50
# GST Breakup Details
# -> (Amount INR)
# GST
# Taxable
# CGST
# SGST
# CESS
# Total
# IND
# Amount
# Amount
# 1
# 890.96
# 22.27
# 22.27
# 935.50
# Angunt Recelved Fran C
# Cstamer
# Card Payment
# 935.50/-
# Saved Rs
# 50/-OnMRP
# **
# generated invoice.

# %%
# Declare the PaddleOCR class
ocr = PaddleOCR()

img_path = "C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice7.jpeg"


# Perform prediction
result = ocr.ocr(img_path, rec=False)
print(result)
# Out:
# [2023/06/28 15:37:54] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25
# ...

# %%
[
  [[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
  [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
  [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
  [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
  [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
  [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
  [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]
]
# Out:
# [[[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
#   [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
#   [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
#   [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
#   [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
#   [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
#   [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]]

# %%
import cv2
import numpy as np

# read image using opencv python
image = cv2.imread("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice7.jpeg")

for row in result[0]:
    # conver float to integer
    row = [[int(r[0]), int(r[1])] for r in row]
    # Draw polyline on image
    cv2.polylines(image, [np.array(row)], True, (255, 0, 0), 1)

cv2.imwrite("out.jpg", image)
# Out:
# True

# %%
result = ocr.ocr("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice7.jpeg")
print(result)
# Out:
# [2023/06/28 15:49:30] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/06/28 15:49:31] ppocr DEBUG: dt_boxes num : 102, elapse : 0.5424931049346924
# [2023/06/28 15:49:47] ppocr DEBUG: rec_res num  : 102, elapse : 15.971005201339722
# ...

# %%
concat_output = "\n".join(row[1][0] for row in result[0])
print(concat_output)
# Out:
# DMart
# AVENUE SUPERMARTS LTD
# CIN：L51900MH2000PLC126473
# GSTIN:36AACCA8432H1ZR
# FSSAI NO.：11512011001964
# DMART HIMAYATHNAGAR
# H.NO.3-6-288/4S5
# DPP OID MLA QUARTERS
# BESIDE TOYATA SHOWROOM
# HYDERGUDA BASHERBAGH ROAD
# HYDERABAD 500029
# Phone:040-23298560
# TAX INVOICE
# B111 No:501801013-002605 8111 Dt:16/01/2023(2:12P
# Vou.No:$138013-0028
# Cashier :PRI/138356
# HSN
# Particulars
# Qty/Kg
# N/Rate
# Value
# 1) CGST @ 0.00%, SGST @0.00%
# 250100 TATA SALT-1kg
# 3
# 25.00
# 2) CGST @ 2.50%, SGST @ 2.50%
# 75.00
# 110100 AASHIRVAAD WHEA-5kg
# 258.00
# 258.00
# 3)CGST@9.00%SGST
# 330510 TRESEMME SMOUS80
# 399.00
# 798.00
# 330590 INDICA NAF BLA
# 26.00
# 52.00
# 340220 RIN LIQUID DE
# 148.00
# 740.00
# 340220 COLIN GLASS
# -ilt
# 1
# 163.00
# 163.00
# 380894 D0MEX D
# SN
# CT-11t
# 3
# 185.00
# 370.00
# 732310 REFLECT
# ESSS
# 3
# 10.00
# 30.00
# 4)CGST
# .50%，
# SGST2.504
# 150990FIGA
# ACEITE-500ml
# 1
# 499.00
# 499.00
# 5
# @9.00%，SGST@9.00%
# 190590
# GLUCOS-80Og
# G
# ...

# %%
# Declare the PaddleOCR class
ocr = PaddleOCR()

img_path = "C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice8.jpeg"


# Perform prediction
result = ocr.ocr(img_path, rec=False)
print(result)
# Out:
# [2023/06/28 15:51:14] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25
# ...

# %%
[
  [[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
  [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
  [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
  [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
  [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
  [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
  [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]
]
# Out:
# [[[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
#   [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
#   [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
#   [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
#   [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
#   [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
#   [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]]

# %%
import cv2
import numpy as np

# read image using opencv python
image = cv2.imread("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice8.jpeg")

for row in result[0]:
    # conver float to integer
    row = [[int(r[0]), int(r[1])] for r in row]
    # Draw polyline on image
    cv2.polylines(image, [np.array(row)], True, (255, 0, 0), 1)

cv2.imwrite("out.jpg", image)
# Out:
# True

# %%
result = ocr.ocr("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice8.jpeg")
print(result)
# Out:
# [2023/06/28 15:52:57] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/06/28 15:52:57] ppocr DEBUG: dt_boxes num : 82, elapse : 0.5068788528442383
# [2023/06/28 15:53:12] ppocr DEBUG: rec_res num  : 82, elapse : 14.789577007293701
# ...

# %%
concat_output = "\n".join(row[1][0] for row in result[0])
print(concat_output)
# Out:
# D'Mart
# Avenue Superinarts Ltd
# CIN：-L51900MH2000PLC126473
# GSTIN:36AACCA8432H1ZR
# FSSAI NO:11512005001860
# DMART AMBERPET
# H.No.2-3-720
# Zindatilismath Road,
# Amberpet.Hyderabad-500013
# Ph0ne:040-27428336Fax:-040-30853599
# TAX INVOICE
# B111 No:500301006-008452 B1110t:07/01/2023(8:47P
# Vou.No :S064006-0224
# Cashler :VEE/064349
# HSN
# Particulars
# Qty/Kg
# N/Rate
# Value
# 1) CGST0.00%,SGST @0.00%
# 250100 TATA R0CK SAL-1Kg
# 1
# 90.00
# 90.00
# 2)CGST@2.50%,SGST@2.50%
# 110100 AASHIRVAAD WHEA-2Kg
# 113.00
# 113.00
# 3)CGST@9.00%,SGST@9.00%
# 190531 BRITANNIA G00D-200g
# 2
# 45.00
# 90.00
# 340540 EX0 ANT B ROUN-700g
# 1
# 140.00
# 140.00
# 340540 EX0 ANT B RDUN-700g
# 1
# 140.00
# 140.00
# 4)CGST@2.50%,SGST@2.50%
# 151550 ANURAG DEEPARAD-11t
# 2
# 135.00
# 270.00
# Items:5
# Qty:
# 8
# 843.00
# GST Breakup Details
# (Amount INR)
# GSr
# Taxable
# CGST
# CESS
# Total
# IND
# Amaunt
# Amount
# 1
# 90.00
# 90.00
# 2
# 107.62
# 2.69
# 113.00
# 3
# 313.56
# 28.22
# 370.00
# ...

# %%
# Declare the PaddleOCR class
ocr = PaddleOCR()

img_path = "C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice9.jpeg"


# Perform prediction
result = ocr.ocr(img_path, rec=False)
print(result)
# Out:
# [2023/06/28 15:54:58] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25
# ...

# %%
[
  [[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
  [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
  [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
  [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
  [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
  [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
  [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]
]
# Out:
# [[[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
#   [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
#   [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
#   [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
#   [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
#   [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
#   [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]]

# %%
import cv2
import numpy as np

# read image using opencv python
image = cv2.imread("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice9.jpeg")

for row in result[0]:
    # conver float to integer
    row = [[int(r[0]), int(r[1])] for r in row]
    # Draw polyline on image
    cv2.polylines(image, [np.array(row)], True, (255, 0, 0), 1)

cv2.imwrite("out.jpg", image)
# Out:
# True

# %%
result = ocr.ocr("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice9.jpeg")
print(result)
# Out:
# [2023/06/28 15:56:27] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/06/28 15:56:28] ppocr DEBUG: dt_boxes num : 98, elapse : 0.508490800857544
# [2023/06/28 15:56:43] ppocr DEBUG: rec_res num  : 98, elapse : 14.545633316040039
# ...

# %%
concat_output = "\n".join(row[1][0] for row in result[0])
print(concat_output)
# Out:
# DMart
# AVENUE SUPERMARTS LTD
# CIN:-L51900MH2000PLC126473
# GSTIN:36AACCA8432H1ZR
# FSSAI NO,:1361601300024
# DMART KAVURI HILLS
# PLOTNO:43/P.4546&48
# HAVURI HILLS ROAD MADHAPUR
# HYDERABAD-500081
# Phone:040-23119921
# TAX INVOICE
# B111No:502001009-001341
# Bill Ot:
# 06/01/2023(1:20PM
# Vou.
# NGS103009-0070
# Cashier :
# PIA/103543
# HSN
# Particulara
# Qty/Kg
# N/Rate
# Value
# 1)CGST @2.50%,SGST@2.50%
# 151550 ANURAG DEEPARAD-11t
# 135.00
# 270.00
# 151590 FORFUNE RICE BR-1It
# 1
# 147.00
# 147.00
# 2) CGST @6.00%,SGST@6.00%
# 200799 KISSAN MIX FRU-700g
# 2
# 195.00
# 390.00
# 3)CGST99.00%SGST
# @9.00%
# 190590 PARLE HI0DE N S-100g
# 3
# 27.00
# 81.00
# 340540 VIM POWER 100L-500g
# 5
# 55.80
# 279.00
# Items:5
# Qty:
# 13
# 1167.00
# GST Breakup
# a1ls
# >(Amount INR)
# GST
# Taxable
# CGST
# SGST
# CESS
# Total
# IND
# Amount
# Amount
# 1
# 397.14
# 9.93
# 417.00
# 2
# 348.22
# 20.89
# 20.
# 390.00
# 3
# 305.08
# 27.46
# 27.46
# 360.00
# SI
# T:
# 1050.44
# 58.28
# 58.28
# ...

# %%
# Declare the PaddleOCR class
ocr = PaddleOCR()

img_path = "C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice10.jpeg"


# Perform prediction
result = ocr.ocr(img_path, rec=False)
print(result)
# Out:
# [2023/06/28 16:03:17] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25
# ...

# %%
[
  [[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
  [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
  [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
  [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
  [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
  [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
  [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]
]
# Out:
# [[[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
#   [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
#   [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
#   [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
#   [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
#   [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
#   [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]]

# %%
import cv2
import numpy as np

# read image using opencv python
image = cv2.imread("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice10.jpeg"
)

for row in result[0]:
    # conver float to integer
    row = [[int(r[0]), int(r[1])] for r in row]
    # Draw polyline on image
    cv2.polylines(image, [np.array(row)], True, (255, 0, 0), 1)

cv2.imwrite("out.jpg", image)
# Out:
# True

# %%
result = ocr.ocr("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice10.jpeg"
)
print(result)
# Out:
# [2023/06/28 16:19:24] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/06/28 16:19:25] ppocr DEBUG: dt_boxes num : 87, elapse : 0.9229612350463867
# [2023/06/28 16:19:53] ppocr DEBUG: rec_res num  : 87, elapse : 27.540183305740356
# ...

# %%
concat_output = "\n".join(row[1][0] for row in result[0])
print(concat_output)
# Out:
# DMart
# AVENUE SUPERMARTS LTD
# CIN:-L51900MH2000PLC126473
# GSTIN:36AACCA8432H1ZR
# FS5AI NO.:1361601300024
# DMART KAVURI HILLS
# PL01NO:43/P.45.46848
# KAVURI HILLS ROAO MADHAPUR
# HYDERABAD-500081
# Ph0ne:040-23119921
# TAX INVOICE
# B111 No :502001009-001074
# Vou.No:Sh03009-0107
# B1Ot：05/01/202312:51PM
# Cashler:PIA/103543
# HSN
# Particulers
# Qty/kg
# N/Rate
# Value
# 1)CGST@2.50%
# SGST@2.50%
# 120400 NUTRAJ FLAX SE-200g
# 1
# 150890 FREE001GROUNDN-11t
# 55.00
# 55.00
# 151219 GOLD OROP SUNFL-11t
# 163.00
# 815.00
# 2
# 148.00
# 296.00
# 2)-005T6.00%,SGST-@6.00%
# 420222ZZZCLOTH BAG
# 18.00
# 18.00
# 3)CGST @9.00%,SGST@9.00%
# 330510 PANTENE PR0-V-340ml
# 1
# 319.00
# 319.00
# 340540 PRIL LIME N VING-3g
# 1
# 110.00
# 110.00
# Items:6
# Qty:
# 11
# 1613.00
# GST Breakup Deta
# (Anount INR)
# GST
# Taxable
# CGST
# GST
# CESS
# Total
# IND
# Anount
# Anouat
# 1
# 1110.48
# 27.76
# 1166.00
# 2
# 16.08
# 96
# 0.96
# 18.00
# 3
# 363.56
# 2.72
# 32.72
# 429.00
# T:
# 1490
# ...

# %%
# Declare the PaddleOCR class
ocr = PaddleOCR()

img_path ="C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice11.jpeg"


# Perform prediction
result = ocr.ocr(img_path, rec=False)
print(result)
# Out:
# [2023/06/28 16:21:51] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25
# ...

# %%
[
  [[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
  [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
  [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
  [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
  [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
  [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
  [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]
]
# Out:
# [[[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
#   [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
#   [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
#   [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
#   [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
#   [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
#   [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]]

# %%
import cv2
import numpy as np

# read image using opencv python
image = cv2.imread("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice11.jpeg")

for row in result[0]:
    # conver float to integer
    row = [[int(r[0]), int(r[1])] for r in row]
    # Draw polyline on image
    cv2.polylines(image, [np.array(row)], True, (255, 0, 0), 1)

cv2.imwrite("out.jpg", image)
# Out:
# True

# %%
result = ocr.ocr("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice11.jpeg")
print(result)
# Out:
# [2023/06/28 16:24:08] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/06/28 16:24:09] ppocr DEBUG: dt_boxes num : 107, elapse : 1.0892603397369385
# [2023/06/28 16:24:41] ppocr DEBUG: rec_res num  : 107, elapse : 31.955345630645752
# ...

# %%
concat_output = "\n".join(row[1][0] for row in result[0])
print(concat_output)
# Out:
# D'Mart
# AVENUE SUPERMARTS LTD
# CIN：L51900MH2000PLC126473
# GSTIN36AACCA8432H1ZR
# FSSAI NO.:11512011001964
# DMART HIMAYATHNAGAR
# H.NO、3-6-288/4S5
# OPP OIO MLA QURS
# BESIDE TOYATA S
# NROOM
# HYUERGUOA BASHER GH ROAD
# HYDERABAD
# Q:J029
# Phone:04
# 298560
# TAX
# 8111：501801008-005005
# S11Ot：28/01/2023(10:00A)
# Vou.NoS138006-0008
# ashier:SAP/138418
# HSN
# Par'ticulass
# Qty/ng
# N/Rate
# Value
# 1)CG5T@2.50%,
# @2.50%
# 090190 BRU GREEN LABE 500g
# 1
# 170.00
# 170.00
# 090230 BR00KE BOND 3R 500g
# 1
# 390.00
# 390.00
# 151590FREE00M RICE BR-11t
# 3
# 147.00
# 2)CE5T@ 9.00%,SUST @9.00%
# 441.00
# 190190 CADBURY BOURNV 200g
# 1
# 108.00
# 108.00
# 210690 MIR RAVA IDLI-1K
# 1
# 185.00
# 185.00
# 340119 PATANJALI SUPE-145g
# 7
# 9.00
# 63.00
# 340220 RIN L00ID DE-800m
# 148.00
# 592.00
# 3)CGST@6.00%,SGST@6.00%
# 42022272 CL0TH BAG
# 1
# 18.00
# 18.00
# Items:8
# Qty:
# 19
# 1967.00
# GST Breakup Details
# (Anount In)
# GST
# faxable
# CGST
# SGST
# CESS
# Total
# IND
# ...

# %%
# Declare the PaddleOCR class
ocr = PaddleOCR()

img_path ="C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice12.jpeg"

# Perform prediction
result = ocr.ocr(img_path, rec=False)
print(result)
# Out:
# [2023/06/28 16:25:46] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25
# ...

# %%
[
  [[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
  [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
  [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
  [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
  [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
  [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
  [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]
]
# Out:
# [[[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
#   [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
#   [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
#   [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
#   [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
#   [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
#   [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]]

# %%
import cv2
import numpy as np

# read image using opencv python
image = cv2.imread("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice12.jpeg")

for row in result[0]:
    # conver float to integer
    row = [[int(r[0]), int(r[1])] for r in row]
    # Draw polyline on image
    cv2.polylines(image, [np.array(row)], True, (255, 0, 0), 1)

cv2.imwrite("out.jpg", image)
# Out:
# True

# %%
result = ocr.ocr("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice12.jpeg")
print(result)
# Out:
# [2023/06/28 16:27:20] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/06/28 16:27:21] ppocr DEBUG: dt_boxes num : 120, elapse : 1.0542540550231934
# [2023/06/28 16:27:57] ppocr DEBUG: rec_res num  : 120, elapse : 35.29403853416443
# ...

# %%
concat_output = "\n".join(row[1][0] for row in result[0])
print(concat_output)
# Out:
# hrougr
# origil
# shall
# food
# 3
# DMart
# ing
# pi
# FSSAI NO:11511007000195
# Upperpally(Attapura)
# 400455
# NEAR PI1LAR ND.198
# UPPERPALLY
# RAJENDRANAGARNER
# HYDERAAA0 500048
# Phone:040-29705890
# TAX TNVOTCE
# B111 NO:502512004-001747
# Vou.No:S151004-0054
# MOA/15156
# HSN
# Particalars
# Quy/Kg
# N/Rate
# Value
# 1)CeST
# SGST2.50%
# G90922 AASHIRVAAD COR-200g
# 1
# 49.00
# 49:00
# 110100 AASHIKVAAD NHEA-1Kg
# 2
# 62.31
# 124,62
# 150790 FORTUNE S0YABEA-11t
# 1
# 148.00
# 148.00
# 151590 FORTUNE RICE BR-11t
# 1
# 147.00
# 147.00
# 2)CGST@6.00%,SGST@6.00%
# 420222 GREY COTTON SHOPPIN
# 1
# 29.00
# 29.00
# 3)CGST@9.00%,SGST@9.00%
# 190590 PARLEHIDE N S-100g
# 2
# 27.00
# 54.00
# 330499 NIVEA C0C0A N-400ml
# 2
# 259.50
# 519.00
# 330510 SUNSILK THICK-650ml
# 1
# 350.00
# 350,00
# 330610 CLOSEUP DEEP A-300g
# 1
# 121.00
# 121.00
# 340111MYS0RE SANDAL -125g
# 2
# 84.60
# 169.20
# 340540 EX0 ANT ROUND -700g
# 8
# 74.00
# 592.00
# 4)CGST@2.50%,SGST
# T@2.50%
# ...

# %%
# Declare the PaddleOCR class
ocr = PaddleOCR()

img_path = "C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice13.jpeg"

# Perform prediction
result = ocr.ocr(img_path, rec=False)
print(result)
# Out:
# [2023/06/28 16:28:53] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25
# ...

# %%
[
  [[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
  [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
  [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
  [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
  [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
  [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
  [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]
]
# Out:
# [[[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
#   [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
#   [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
#   [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
#   [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
#   [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
#   [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]]

# %%
import cv2
import numpy as np

# read image using opencv python
image = cv2.imread("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice13.jpeg")


for row in result[0]:
    # conver float to integer
    row = [[int(r[0]), int(r[1])] for r in row]
    # Draw polyline on image
    cv2.polylines(image, [np.array(row)], True, (255, 0, 0), 1)

cv2.imwrite("out.jpg", image)
# Out:
# True

# %%
result = ocr.ocr("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice13.jpeg")
print(result)
# Out:
# [2023/06/28 16:31:46] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/06/28 16:31:47] ppocr DEBUG: dt_boxes num : 74, elapse : 1.0470337867736816
# [2023/06/28 16:32:09] ppocr DEBUG: rec_res num  : 74, elapse : 21.850938320159912
# ...

# %%
concat_output = "\n".join(row[1][0] for row in result[0])
print(concat_output)
# Out:
# turer.
# befinal.
# Nara
# DMart
# CIN：L51900MH2000PLC126473
# GSTIN:36AACCA8432H1ZR
# FSSAI NO:11511007000195
# Upperpally(Attapura)
# NEAR PILLAR NO.198
# UPPERPALLY
# RAJENDRANAGARNER
# HYDERABAD 500048
# phone:040-29705890
# TAX INVOICE
# PRI/151560
# Vou.No:S151012-0086
# N/Rate
# Value
# HSN
# Particulars
# 18.00
# 72.
# SGST0900
# 189.00
# 378.0
# 340111PEAR5
# 2
# 6
# 450.00
# Items!
# han
# Qty:
# GST Breakup Details
# (Amount INR)
# GST
# Taxable
# CGST
# SGST
# CESS
# Total
# IND
# Amount
# Amount
# 68.58
# 1.71
# 1.71
# 72.00
# 1
# 2
# 320.34
# 28.83
# 28.83
# 378.00
# 30.54
# 30.54
# 450.00
# T:
# 388.92
# Amount Recelved Fron Customer
# 450.00/
# UPI Payment :
# Saved fs.178 00/-0n Mpp
# 水
# This Is computer generated invoice
# ICICI BANK
# M001635025DMARIUPP

# %%
# Declare the PaddleOCR class
ocr = PaddleOCR()

img_path ="C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice14.jpeg"

# Perform prediction
result = ocr.ocr(img_path, rec=False)
print(result)
# Out:
# [2023/06/28 16:34:08] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25
# ...

# %%
[
  [[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
  [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
  [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
  [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
  [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
  [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
  [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]
]
# Out:
# [[[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
#   [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
#   [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
#   [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
#   [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
#   [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
#   [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]]

# %%
import cv2
import numpy as np

# read image using opencv python
image = cv2.imread("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice14.jpeg")

for row in result[0]:
    # conver float to integer
    row = [[int(r[0]), int(r[1])] for r in row]
    # Draw polyline on image
    cv2.polylines(image, [np.array(row)], True, (255, 0, 0), 1)

cv2.imwrite("out.jpg", image)
# Out:
# True

# %%
result = ocr.ocr("C:\\Users\\Lenovo\\Desktop\\Project_111\\Invoices\\Invoice14.jpeg")
print(result)
# Out:
# [2023/06/28 16:35:39] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/06/28 16:35:40] ppocr DEBUG: dt_boxes num : 83, elapse : 1.0105953216552734
# [2023/06/28 16:36:06] ppocr DEBUG: rec_res num  : 83, elapse : 25.159242630004883
# ...

# %%
concat_output = "\n".join(row[1][0] for row in result[0])
print(concat_output)
# Out:
# uld be providedby
# sk)
# D'Mart
# AVENUE SUPERMARTS LTD
# CIN :L51900MH2000PLC126173
# 413483
# GSTIN:36AACCA8432H1ZR
# FSSAI ND.:13617014000881
# DMART S D ROAD
# 112,SAROJINI DEVI ROAD
# SECUNDERABAD
# Ph0ne:040-27718041
# TAX INVOICE
# a111 No:501312019-003153
# B111Dt:22/12/2022(5:12p
# Vou.No:S142019-0089
# Cashier :LI7/142501
# HSN
# Particulars
# Qty/ng
# N/Rate
# Value
# 1)CGSY@2.50%,SGST2.50%
# 51311 MLF NIRMAL COCO-11t
# 1
# 225.00
# 225.0
# 2)CGST@6.00%,SGST @6.00%
# 210390 CHINGS RED CHI-200g
# 1
# 38.00
# 38.00
# 3) CGST @ 9.00%, SGST @9.00%
# 340119 PATANJALI SUPE-145g
# 6
# 9.00
# 54.00
# Itens:3
# Qty:
# 8
# 317.00
# GST Breakup Details
# > (Amount INR)
# GST
# Taxable
# CGST
# SGST
# CESS
# Total
# IND
# Amount
# Amount
# 1
# 214.28
# 5.36
# 5.36
# 225.00
# 2
# 33.92
# 2.04
# 2.04
# 38.00
# 3
# 45.78
# 4.12
# 4.12
# 54.00
# T:
# 293.96
# 11.52
# 11.
# 317.00
# Amount Recefved
# stomer
# Lasr
# 400.00
# Balance Paid
# d In Casb
# 83.00
# **Saved Ro
# 108.00/-0nMRP
# ...

# %%
# Declare the PaddleOCR class
ocr = PaddleOCR()

img_path = r"C:\Users\Lenovo\Desktop\Project_111\Invoices\Invoice15.jpeg"


# Perform prediction
result = ocr.ocr(img_path, rec=False)
print(result)
# Out:
# [2023/06/28 16:37:52] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25
# ...

# %%
[
  [[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
  [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
  [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
  [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
  [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
  [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
  [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]
]
# Out:
# [[[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
#   [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
#   [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
#   [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
#   [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
#   [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
#   [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]]

# %%
import cv2
import numpy as np

# read image using opencv python
image = cv2.imread(r"C:\Users\Lenovo\Desktop\Project_111\Invoices\Invoice15.jpeg")

for row in result[0]:
    # conver float to integer
    row = [[int(r[0]), int(r[1])] for r in row]
    # Draw polyline on image
    cv2.polylines(image, [np.array(row)], True, (255, 0, 0), 1)

cv2.imwrite("out.jpg", image)
# Out:
# True

# %%
result = ocr.ocr(r"C:\Users\Lenovo\Desktop\Project_111\Invoices\Invoice15.jpeg")
print(result)
# Out:
# [2023/06/28 16:42:22] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/06/28 16:42:23] ppocr DEBUG: dt_boxes num : 62, elapse : 0.8366293907165527
# [2023/06/28 16:42:44] ppocr DEBUG: rec_res num  : 62, elapse : 21.091463804244995
# ...

# %%
concat_output = "\n".join(row[1][0] for row in result[0])
print(concat_output)
# Out:
# FS6AI NO.:13617014000881
# DMART S D ROAD
# 112,SAROJINI DEVI ROAD
# SECUNDERABAD
# phone:040.27718041
# TAX INVOICE
# B111Dt：19/12/20224-43
# B111 No:581312023-019447
# Vou.No$142023-0133
# Cashier :REN/142402
# Particulars
# ty/ng
# N/Rate
# Value
# HSN
# 11c6sf@9.00%,$681@9.00%
# 330499NIVEASKINMI-400ml
# 1
# 265.00
# 265.0
# 340540 VIM BAR 3UX200-600g
# 5
# 60.00
# 300.00
# Items:2
# Qty:
# 6
# 565.00
# GST Breakup Details
# (Amount INR)
# GST
# Taxable
# COST
# SGST
# CESS
# Total
# IND
# Anount
# Amount
# 1
# 478.82
# 43.09
# 43.09
# 565.0
# Akaunt Recaived Fron Custom
# Card Payment
# 15.00/
# Savof Rs.185.00
# OFMRP**
# Thia is computer generated Invoice.
# Date/1ime :2022-12-19116:43:30
# CARDNUM:XXXXKXXXKXXXB719
# wipe
# CARD TYPE:VISA
# EXPIRY:XX/XX
# PPR CODE :356098
# RRN:000000016442

# %%
# Declare the PaddleOCR class
ocr = PaddleOCR()

img_path = r"C:\Users\Lenovo\Desktop\Project_111\Invoices\Invoice16.jpeg"

# Perform prediction
result = ocr.ocr(img_path, rec=False)
print(result)
# Out:
# [2023/06/28 16:43:45] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25
# ...

# %%
[
  [[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
  [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
  [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
  [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
  [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
  [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
  [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]
]
# Out:
# [[[[73.0, 377.0], [590.0, 377.0], [590.0, 401.0], [73.0, 401.0]],
#   [[73.0, 348.0], [641.0, 348.0], [641.0, 368.0], [73.0, 368.0]],
#   [[71.0, 316.0], [688.0, 317.0], [688.0, 338.0], [71.0, 337.0]],
#   [[72.0, 228.0], [205.0, 230.0], [204.0, 279.0], [71.0, 276.0]],
#   [[72.0, 162.0], [636.0, 168.0], [636.0, 218.0], [71.0, 211.0]],
#   [[74.0, 104.0], [670.0, 104.0], [670.0, 146.0], [74.0, 146.0]],
#   [[71.0, 53.0], [516.0, 53.0], [516.0, 76.0], [71.0, 76.0]]]]

# %%
import cv2
import numpy as np

# read image using opencv python
image = cv2.imread(r"C:\Users\Lenovo\Desktop\Project_111\Invoices\Invoice16.jpeg")

for row in result[0]:
    # conver float to integer
    row = [[int(r[0]), int(r[1])] for r in row]
    # Draw polyline on image
    cv2.polylines(image, [np.array(row)], True, (255, 0, 0), 1)

cv2.imwrite("out.jpg", image)
# Out:
# True

# %%
result = ocr.ocr(r"C:\Users\Lenovo\Desktop\Project_111\Invoices\Invoice16.jpeg")
print(result)
# Out:
# [2023/06/28 16:45:43] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process
# [2023/06/28 16:45:44] ppocr DEBUG: dt_boxes num : 112, elapse : 1.016108512878418
# [2023/06/28 16:46:18] ppocr DEBUG: rec_res num  : 112, elapse : 33.76564431190491
# ...

# %%
concat_output = "\n".join(row[1][0] for row in result[0])
print(concat_output)
# Out:
# BENGALURU
# sRD14
# agar
# U
# 18
# AVENUE SUPERMARTS LTD
# CIN：L51900MH2000PLC126473
# GSTIN:36AACCA8432H1ZR
# FSSAI NO.:13617014000681
# DMART S D ROAD
# 112SAROJINI DEVY RDAD
# SECUNDERAZAD
# Phone:040-2771
# 80
# TAXINVOI
# B111 No:501312019-00119
# Bill
# 13/12/2022(3:41PM
# Vou..
# No：S142019-0056
# Cashie
# DES/142499
# HSN
# Particulars
# Qty
# N/Rate
# Value
# 1)CGST@2.50%，SGST
# 2450%
# 090422 AASHIRVAAD CHI 500g
# 091030 AASHIRVAAD TUR 100g
# 155.00
# 155.00
# 1
# 21.00
# 21.00
# 2)CGST9.00%,SGST@9.00%
# 330499 NIVEA SKIN MI-400ml
# 1
# 265.00
# 265.00
# 330610 COLGATE DENTAL-100g
# 61.00
# 122.00
# 330810 PATANJALIREG -100g
# 2
# 50.00
# 100.00
# 340130 NIVEA MEN 0IL -100g
# 189.00
# 189.00
# 340540 VIM DISHWASH BA25g
# 5
# 9.30
# 46.50
# 380891HIT RE0C0CKR/400ml
# 195.00
# 195.00
# B21210 GIL1ETEE GUAR&31R
# 108.00
# 108.00
# 3)CGSTG0.00%SGSTG000%
# SALE ROUND OFT ACCOUNT
# (-)0..
# 0.50
# Items:9
# Qty:
# 15
# 1201.00
# GST Breakup D&tals
# >(AmountINR)
# GST
# Taxable
# ...

# %%
#Invoice 1
import re

text = """
TAX INVOIC
AVENUE SUPERMARTS LTD
Invoice No.
CIN：L51900MH2000PLC126473
Invoice Date
GSTIN：36AACCA8432H1ZR
FSSAI No:13620011000658
SHIPTO
TRIDDYSIN
DMART HIMAYATHNAGAR
H.NO.3-6-288/4$5
OPP OID MLA QUARTERS
BESIDE TOYATA SHOWROOM
HYDERGUDA BASHERBAGH ROAD
MRP
RA
HYDERABAD 500029
243
187
Phone:040-23298560
TAX INVOICE
Bi11 No :501802014-012959
Bi11 Dt:03/02/2023 V&u.:S138014-0242
Cashier:ANT/138322
n1me-:12:55PM
HSN
Particular Qty/Kg Rate
Value
T
1CGST@ 0.00% SGST@0.00%
250100AASHIR-1kg
2
26.32
52. 64
2 CGST@ 9.00% SGST@
9.00%
330499NIVE-400m
000
510.00
Items:
2 Qty:
Amt
562.64
<-- GST Breakup
(Amount INR)
GSTTaxable
SGST
CESS
Total
IND Amount
Amount
52.64
52.64
2
432.20
38.9038.90
510.00
484.8438.9038.90
562.64
T
<-- Amount Recd From Customer -->
562.64
"""

bill_number_pattern = r"Bi11\sNo\s:(\d{9}-\d{6})"
bill_number_match = re.search(bill_number_pattern, text)

if bill_number_match:
    bill_number = bill_number_match.group(1)
    print(bill_number)
bill_date_pattern = r"Bi11\sDt:(\d{2}/\d{2}/\d{4})"
bill_date_match = re.search(bill_date_pattern, text)

if bill_date_match:
    bill_date = bill_date_match.group(1)
    print(bill_date)
product_name_pattern = r"\d+\s(.+)"
product_name_match = re.search(product_name_pattern, text)

if product_name_match:
    product_name = product_name_match.group(1)
    print(product_name)
quantity_pattern = r"\n(\d+)\n"
quantity_match = re.search(quantity_pattern, text)

if quantity_match:
    quantity = quantity_match.group(1)
    print(quantity)
price_pattern = r"\n(\d+\.\d{2})\n"
price_match = re.search(price_pattern, text)

if price_match:
    price = price_match.group(1)
    print(price)
# Out:
# 501802014-012959
# 03/02/2023
# Invoice Date
# 243
# 26.32

# %%
#invoice 2

text = """
AVENUE SUPERMARTS LTD
CIN NO :L51900MH2000PLC126473
GSTIN：36AACCA8432H1ZR
FSSAI No:13620011000658
DMART HIMAYATHNAGAR
H.NO.3-6-288/4$5
OPP OID MLA QUARTERS
BESIDE TOYATA SHOWROOM
HYDERGUDA BASHERBAGH ROAD
HYDERABAD500029
Phone:040-23298560
TAX INVOICE
B111No:501803014-017065
Bi11 Dt:06/03/2023 Vou.:S138014-0568
Cashier:MVS/138433
-Time :7:16PM
HSN
Particuiar Qty/Kg
Value
1CGST@6.00%SGST@6.00%
170490 GULA-100g
2
15
30.00
2 CGSTQ 9.00% SGSTQ 9.00%
190590L0TTE-336g
1
105
105.00
340220 RIN-800ml
4
146.00
584.00
Items:
3Qty:
Amt
19.00
GST Breakup Detaiis
(Amount
NR)
GST TaxableCGST
SGST
CESS
Total
IND Amount
Amount
26.78
1.61161
30.00
2
583.90
52.5552.55
689.00
610.6854.1654.16
719.00
"""

bill_number_pattern = r"B111No:(\d{9}-\d{6})"
bill_number_match = re.search(bill_number_pattern, text)

if bill_number_match:
    bill_number = bill_number_match.group(1)
    print("Bill Number:", bill_number)

bill_date_pattern = r"Bi11\sDt:(\d{2}/\d{2}/\d{4})"
bill_date_match = re.search(bill_date_pattern, text)

if bill_date_match:
    bill_date = bill_date_match.group(1)
    print("Bill Date:", bill_date)

product_name_pattern = r"\d+\s+(.+)\n\d+\n\d+\.\d{2}"
product_name_match = re.findall(product_name_pattern, text)

if product_name_match:
    product_names = [name.strip() for name in product_name_match]
    print("Product Names:", product_names)

quantity_pattern = r"\n(\d+)\n\d+\n\d+\.\d{2}"
quantity_match = re.findall(quantity_pattern, text)

if quantity_match:
    quantities = [quantity.strip() for quantity in quantity_match]
    print("Quantities:", quantities)

price_pattern = r"\n\d+\n(\d+\.\d{2})"
price_match = re.findall(price_pattern, text)

if price_match:
    prices = [price.strip() for price in price_match]
    print("Prices:", prices)
# Out:
# Bill Number: 501803014-017065
# Bill Date: 06/03/2023
# Product Names: ['340220 RIN-800ml', '30.00']
# Quantities: ['2', '1']
# Prices: ['30.00', '105.00', '146.00', '583.90']

# %%
#Invoice 3
import re

text = """
e
S
DUB
DMart
AVENUE SUPERMARTS LTD
CIN No : L51900MH2000PLC126473
GSTIN36AACCA8432H1ZR
FSSAI No :13620011000658
DMART SHEKHPETH
B-1-299/5,
Duties Bullding,Al-Hamra Colony,
Shalkpet Tolchowki,Hyd-500008
Phone:
7207851378175
TAX INVOICE
Bill Dt
04/04/2023
9:49P1)
B11lNo501904020-000797
Cashier
QL/108569
Vou.No:S108020-0227
Qty/K
N/Rate
Particulars
Value
HSN
1)CGST@2.50%,SGST@2
150810 ASGRAND DFILT-11t
177.00
354.00
151219FREEDOMSUNFL(W-51t
2
660.00
1320.00
190240 BAMBINO VERMI-1.4kg
3
107.00
321.00
2)CGST@6.00%，SGSF@6.00%
1
17.00
17.00
300490 HAPPYDENT WHITE
3)CGST@9.00%，5T@9.00%
330710 GILLETE FOAM F1Bg
1
230.00
230.00
330720 KS SPARK DE020ml
1
180.00
180.00
4)CGST@2.50%SGST电2.50%
151550 ANURAG DEEPARAD-11t
2
125.00
250.00
Qty:
12
2672.00
Items:
Breakup Detalls
>(Amount INR)
CST
Taxable
CGST
SGST
CESS
Total
GST
ND
Armiount
Amaunt
1900.00
47.50
47.50
1995.00
15.18
0.91
0.91
17.00
2
347.46
31.27
31.27
410.00
3
238.10
5.95
5.95
250.00
4
T:
2500.74
85.63
85.83
2672.00"""

bill_number = re.search(r'B11lNo(\d+-\d+)', text)
bill_date = re.search(r'Bill\sDt\D*(\d{2}/\d{2}/\d{4})', text)
product_names = re.findall(r'\d+\)\D*(.*?)\n', text)
quantities = re.findall(r'\n\d+\n(\d+)', text)
prices = re.findall(r'\n(\d+\.\d{2})\n', text)

if bill_number:
    bill_number = bill_number.group(1)
else:
    bill_number = "Not found"

if bill_date:
    bill_date = bill_date.group(1)
else:
    bill_date = "Not found"

print("Bill Number:", bill_number)
print("Bill Date:", bill_date)
print("Product Names:", product_names)
print("Quantities:", quantities)
print("Prices:", prices)
# Out:
# Bill Number: 501904020-000797
# Bill Date: 04/04/2023
# Product Names: ['11lNo501904020-000797', '2.50%,SGST@2', '6.00%，SGSF@6.00%', '9.00%，5T@9.00%', '2.50%SGST电2.50%']
# Quantities: ['660', '107', '17', '230', '180', '125', '2672', '347', '238']
# Prices: ['177.00', '660.00', '107.00', '17.00', '230.00', '180.00', '125.00', '2672.00', '1900.00', '47.50', '15.18', '0.91', '347.46', '31.27', '238.10', '5.95', '2500.74', '85.83']

# %%
#Invoice 4

text = """
DMart
AVENUE SUPERMARTS LTD
CINL51900MH2000PLC126473
GSTIN:36AACCA8432H1ZR
FSSAINo:13620013000657
DMART KAVURI HILLS
PLOT NO:43/P,45,46&48
KAVURI HILLS RDAD MADHAPUR
HYDERABAD-500081
Phone:040-23119921
TAX INVOICE
8111 No502002018-002273 B111 Dt:14/02/20232:51PM
Vou.No:S103018-0043
Cashier : SAN/103668
Value
HSN
Particulars
Qty/kg
N/Rate
Value
.00V
1)CGST@2.50%,SGST@2.50%
150890FREED0MGROUNON-11t
1
166.00
166.00
Items:1
Qty:
1
166.00
GST Breakup Details
>(Amotnt INR)
GST
Taxable
CaST
SGST
CESS
atal
IND
Amount
Amount
158.10
3.95
166.00
1
Anount Recel
166.00/
Card Payrent
Saved Rs.19.00/0n:MRp
"""

bill_number = re.search(r'No(\d+-\d+)', text)
bill_date = re.search(r'Dt:(\d{2}/\d{2}/\d{4})', text)
product_name = re.search(r'(\d+)\)\D*(.*?)\n', text)
quantity = re.search(r'\)\n(\d+)\n', text)
price = re.search(r'\n(\d+\.\d{2})\n\d+\n\d+\n', text)

if bill_number:
    bill_number = bill_number.group(1)
else:
    bill_number = "Not found"

if bill_date:
    bill_date = bill_date.group(1)
else:
    bill_date = "Not found"

if product_name:
    product_name = product_name.group(2)
else:
    product_name = "Not found"

if quantity:
    quantity = quantity.group(1)
else:
    quantity = "Not found"

if price:
    price = price.group(1)
else:
    price = "Not found"

print("Bill Number:", bill_number)
print("Bill Date:", bill_date)
print("Product Name:", product_name)
print("Quantity:", quantity)
print("Price:", price)
# Out:
# Bill Number: 502002018-002273
# Bill Date: 14/02/2023
# Product Name: 2.50%,SGST@2.50%
# Quantity: Not found
# Price: Not found

# %%
#Invoice 5

text = '''D"Mart
CIN:L51900MH2000PLC126473
GSTIN:36AACCA8432H1ZR
FSSAI No :1362001500023B
Upperpally(Attapura)
NEAR PILLAR NO.198
UPPERPALLY
RAJENDRANAGARNER
HYDERABA0 50004B
AXINVOICE
B111 No :502502012-002653 B111Dt :13/02/20233:48P
Vou.No:S151012-0067
Cashler : NAB/151573
HSN
Particulars
Qty/ng
N/Rate
Value
1) CGST @9.00%,SGST @9.00%
340250 SURF EXCEL MATI-21t
2
399.00
798.00
Items:1
Qty
2
8.00
Gsr Breakup Details
(Amount Inn)
GST
Taxable
CGST
SGST
CESS
Total
IND
Arnaunt
Amount
1
676.28
60.86
60.86
798.00
Amount Recetyeu From Customer
Card Payment :
798.00-3
**Saved Rs.162.00/-UnMRP**'''

# Extracting Bill Number
bill_number = re.search(r'B111 No\s*:(.*?)\s', text).group(1)

# Extracting Bill Date
bill_date = re.search(r'B111Dt\s*:(.*?)\s', text).group(1)

# Extracting Product Name, Quantity, and Value
table_data = re.findall(r'(\d+)\s*(.*?)\n(\d+)\n(.*?)\n', text)
product_names = [data[1] for data in table_data]
quantities = [data[2] for data in table_data]
values = [data[3] for data in table_data]

print("Bill Number:", bill_number)
print("Bill Date:", bill_date)
print("Product Names:", product_names)
print("Quantities:", quantities)
print("Values:", values)
# Out:
# Bill Number: 502502012-002653
# Bill Date: 13/02/20233:48P
# Product Names: ['SURF EXCEL MATI-21t', 'Qty']
# Quantities: ['2', '2']
# Values: ['399.00', '8.00']

# %%
#Invoice 6
import re

text = """
D"Mart
AVENUE SUPERMARTS LTD
CIN No ：L51900MH2000PLC126473
GSTIN:36AACCA8432H1ZR
FSSAI No :13620013000657
DMART KAVURI HILLS
PLOTNO:43/P.45.46848
KAVURI HILLS ROAD MADHAPUR
HYDERABAD-500081
Phone:040-23119921
TAX INVOICE
Br1l No:502003017-004782B
B111DE：06/03/2023(12:47PM
You. No :S103017-0016
CashMer : RAJ/103450
NSN
Particulars
Qty/kg
N/Rate
Value
CGST@2.50%,SGST 2.50%
150890 FREE0DM GROUNDN-11t
5
178.00
890.00
190410 KURMUR-500g
1
45.50
45.50
Items: 2
Qty:
6
935.50
GST Breakup Details
-> (Amount INR)
GST
Taxable
CGST
SGST
CESS
Total
IND
Amount
Amount
1
890.96
22.27
22.27
935.50
Angunt Recelved Fran C
Cstamer
Card Payment
935.50/-
Saved Rs
50/-OnMRP
**
"""

# Extracting Bill Number
bill_number = re.search(r'Br1l No:(.*?)B', text).group(1).strip()

# Extracting Bill Date
bill_date = re.search(r'B111DE：(.*?)\(', text).group(1).strip()

# Extracting Product Names, Quantities, and Prices
table_data = re.findall(r'([\d]+)\s*(.*?)\s+([\d.]+)\s+([\d.]+)', text)
product_names = [data[1] for data in table_data]
quantities = [data[0] for data in table_data]
prices = [data[2] for data in table_data]

print("Bill Number:", bill_number)
print("Bill Date:", bill_date)
print("Product Names:", product_names)
print("Quantities:", quantities)
print("Prices:", prices)
# Out:
# Bill Number: 502003017-004782
# Bill Date: 06/03/2023
# Product Names: ['FREE0DM GROUNDN-11t', '190410 KURMUR-500g', 'Qty:', '890.96']
# Quantities: ['150890', '00', '2', '1']
# Prices: ['5', '1', '6', '22.27']

# %%
#Invoice 7

text = """
DMart
AVENUE SUPERMARTS LTD
CIN：L51900MH2000PLC126473
GSTIN:36AACCA8432H1ZR
FSSAI NO.：11512011001964
DMART HIMAYATHNAGAR
H.NO.3-6-288/4S5
DPP OID MLA QUARTERS
BESIDE TOYATA SHOWROOM
HYDERGUDA BASHERBAGH ROAD
HYDERABAD 500029
Phone:040-23298560
TAX INVOICE
B111 No:501801013-002605 8111 Dt:16/01/2023(2:12P
Vou.No:$138013-0028
Cashier :PRI/138356
HSN
Particulars
Qty/Kg
N/Rate
Value
1) CGST @ 0.00%, SGST @0.00%
250100 TATA SALT-1kg
3
25.00
2) CGST @ 2.50%, SGST @ 2.50%
75.00
110100 AASHIRVAAD WHEA-5kg
258.00
258.00
3)CGST@9.00%SGST
330510 TRESEMME SMOUS80
399.00
798.00
330590 INDICA NAF BLA
26.00
52.00
340220 RIN LIQUID DE
148.00
740.00
340220 COLIN GLASS
-ilt
1
163.00
163.00
380894 D0MEX D
SN
CT-11t
3
185.00
370.00
732310 REFLECT
ESSS
3
10.00
30.00
4)CGST
.50%，
SGST2.504
150990FIGA
ACEITE-500ml
1
499.00
499.00
5
@9.00%，SGST@9.00%
190590
GLUCOS-80Og
G
2
80.00
160.00
Items:10
Qty:
22
3145:00
(Armount INR)
Gsr Breakup Details
CAS!
CESS
Total
GST
Taxable
Amount
IND
Amount
75.00
1
150
258.00
2
24
"""

# Extracting Bill Number
bill_number = re.search(r'B111 No:(.*?)\s', text).group(1)

# Extracting Bill Date
bill_date = re.search(r'Dt:(\d+/\d+/\d+)', text).group(1)

# Extracting Product Names, Quantities, and Prices
table_data = re.findall(r'(\d+)\s+(.*?)\s+([\d.]+)\s*$', text, flags=re.MULTILINE)
product_names = [data[1] for data in table_data if not data[0].isdigit()]
quantities = [data[0] for data in table_data if data[0].isdigit()]
prices = [data[2] for data in table_data if data[0].isdigit()]

print("Bill Number:", bill_number)
print("Bill Date:", bill_date)
print("Product Names:", product_names)
print("Quantities:", quantities)
print("Prices:", prices)
# Out:
# Bill Number: 501801013-002605
# Bill Date: 16/01/2023
# Product Names: []
# Quantities: ['250100', '00', '110100', '330510', '00', '00', '1', '3', '3', '1', '5', '2', '10', '00', '00']
# Prices: ['3', '75.00', '258.00', '399.00', '26.00', '148.00', '163.00', '370.00', '30.00', '499.00', '190590', '160.00', '22', '150', '24']

# %%
#Invoice 8

text = """
D'Mart
Avenue Superinarts Ltd
CIN：-L51900MH2000PLC126473
GSTIN:36AACCA8432H1ZR
FSSAI NO:11512005001860
DMART AMBERPET
H.No.2-3-720
Zindatilismath Road,
Amberpet.Hyderabad-500013
Ph0ne:040-27428336Fax:-040-30853599
TAX INVOICE
B111 No:500301006-008452 B1110t:07/01/2023(8:47P
Vou.No :S064006-0224
Cashler :VEE/064349
HSN
Particulars
Qty/Kg
N/Rate
Value
1) CGST0.00%,SGST @0.00%
250100 TATA R0CK SAL-1Kg
1
90.00
90.00
2)CGST@2.50%,SGST@2.50%
110100 AASHIRVAAD WHEA-2Kg
113.00
113.00
3)CGST@9.00%,SGST@9.00%
190531 BRITANNIA G00D-200g
2
45.00
90.00
340540 EX0 ANT B ROUN-700g
1
140.00
140.00
340540 EX0 ANT B RDUN-700g
1
140.00
140.00
4)CGST@2.50%,SGST@2.50%
151550 ANURAG DEEPARAD-11t
2
135.00
270.00
Items:5
Qty:
8
843.00
GST Breakup Details
(Amount INR)
GSr
Taxable
CGST
CESS
Total
IND
Amaunt
Amount
1
90.00
90.00
2
107.62
2.69
113.00
3
313.56
28.22
370.00
4
257.14
6.43
6.43
270.00
T:
768.32
37.34
37.34
843.00"""

# Extracting Bill Number
bill_number = re.search(r'B111 No:(.*?)\s', text).group(1)

# Extracting Bill Date
bill_date = re.search(r'B1110t:(.*?)\s', text).group(1)

# Extracting Product Names, Quantities, and Prices
table_data = re.findall(r'(\d+)\s(.*?)\n(\d+)\n(\d+\.\d+)', text)
product_names = [data[1] for data in table_data]
quantities = [data[2] for data in table_data]
prices = [data[3] for data in table_data]

print("Bill Number:", bill_number)
print("Bill Date:", bill_date)
print("Product Names:", product_names)
print("Quantities:", quantities)
print("Prices:", prices)
# Out:
# Bill Number: 500301006-008452
# Bill Date: 07/01/2023(8:47P
# Product Names: ['TATA R0CK SAL-1Kg', 'BRITANNIA G00D-200g', '340540 EX0 ANT B ROUN-700g', '340540 EX0 ANT B RDUN-700g', 'ANURAG DEEPARAD-11t', 'Qty:', '90.00', '113.00', '370.00']
# Quantities: ['1', '2', '1', '1', '2', '8', '2', '3', '4']
# Prices: ['90.00', '45.00', '140.00', '140.00', '135.00', '843.00', '107.62', '313.56', '257.14']

# %%
#Invoice 9
import re

text = '''DMart
AVENUE SUPERMARTS LTD
CIN:-L51900MH2000PLC126473
GSTIN:36AACCA8432H1ZR
FSSAI NO,:1361601300024
DMART KAVURI HILLS
PLOTNO:43/P.4546&48
HAVURI HILLS ROAD MADHAPUR
HYDERABAD-500081
Phone:040-23119921
TAX INVOICE
B111No:502001009-001341
Bill Ot:
06/01/2023(1:20PM
Vou.
NGS103009-0070
Cashier :
PIA/103543
HSN
Particulara
Qty/Kg
N/Rate
Value
1)CGST @2.50%,SGST@2.50%
151550 ANURAG DEEPARAD-11t
135.00
270.00
151590 FORFUNE RICE BR-1It
1
147.00
147.00
2) CGST @6.00%,SGST@6.00%
200799 KISSAN MIX FRU-700g
2
195.00
390.00
3)CGST99.00%SGST
@9.00%
190590 PARLE HI0DE N S-100g
3
27.00
81.00
340540 VIM POWER 100L-500g
5
55.80
279.00
Items:5
Qty:
13
1167.00
GST Breakup
a1ls
>(Amount INR)
GST
Taxable
CGST
SGST
CESS
Total
IND
Amount
Amount
1
397.14
9.93
417.00
2
348.22
20.89
20.
390.00
3
305.08
27.46
27.46
360.00
SI
T:
1050.44
58.28
58.28
1167.00
Amount Received Fram
Card Paymnent :
7.00/-
**
**
Saved Rs.343.00/-On MRP'''

# Extracting Bill Number
bill_number = re.search(r'B111No:(.*?)\s', text).group(1)

# Extracting Bill Date
bill_date = re.search(r'Bill Ot:\n(.*?)\(', text).group(1)

# Extracting Product Names, Quantities, and Prices
table_data = re.findall(r'(\d+)\s(.*?)\n(\d+)\n(.*?)\n', text)
product_names = [data[1] for data in table_data]
quantities = [data[2] for data in table_data]
prices = [data[3] for data in table_data]

print("Bill Number:", bill_number)
print("Bill Date:", bill_date)
print("Product Names:", product_names)
print("Quantities:", quantities)
print("Prices:", prices)
# Out:
# Bill Number: 502001009-001341
# Bill Date: 06/01/2023
# Product Names: ['151590 FORFUNE RICE BR-1It', 'KISSAN MIX FRU-700g', 'PARLE HI0DE N S-100g', '340540 VIM POWER 100L-500g', 'Qty:', '417.00']
# Quantities: ['1', '2', '3', '5', '13', '2']
# Prices: ['147.00', '195.00', '27.00', '55.80', '1167.00', '348.22']

# %%
#Invoice 10
import re

text = """
DMart
AVENUE SUPERMARTS LTD
CIN:-L51900MH2000PLC126473
GSTIN:36AACCA8432H1ZR
FS5AI NO.:1361601300024
DMART KAVURI HILLS
PL01NO:43/P.45.46848
KAVURI HILLS ROAO MADHAPUR
HYDERABAD-500081
Ph0ne:040-23119921
TAX INVOICE
B111 No :502001009-001074
Vou.No:Sh03009-0107
B1Ot：05/01/202312:51PM
Cashler:PIA/103543
HSN
Particulers
Qty/kg
N/Rate
Value
1)CGST@2.50%
SGST@2.50%
120400 NUTRAJ FLAX SE-200g
1
150890 FREE001GROUNDN-11t
55.00
55.00
151219 GOLD OROP SUNFL-11t
163.00
815.00
2 148.00
296.00
2)-005T6.00%,SGST-@6.00%
420222ZZZCLOTH BAG
18.00
18.00
3)CGST @9.00%,SGST@9.00%
330510 PANTENE PR0-V-340ml
1
319.00
319.00
340540 PRIL LIME N VING-3g
1
110.00
110.00
Items:6
Qty:
11
1613.00
GST Breakup Deta
(Anount INR)
GST
Taxable
CGST
GST
CESS
Total
IND
Anount
Anouat
1
1110.48
27.76
1166.00
2
16.08
96
0.96
18.00
3
363.56
2.72
32.72
429.00
T:
1490
61.44
61.44
1613.00
Ariount Received Fran Customer
Card Payment :
1613.00/"""

# Extracting Bill Number
bill_number = re.search(r'B111 No\s*:(.*?)\s', text).group(1)

# Extracting Bill Date
bill_date = re.search(r'B1Ot：(.*?)\s', text).group(1)

# Extracting Product Names
product_names = re.findall(r'\d+\s+(.*?)\n', text)

# Extracting Quantities
quantities = re.findall(r'\n(\d+)\n', text)

# Extracting Prices
prices = re.findall(r'(\d+\.\d{2})\n', text)

print("Bill Number:", bill_number)
print("Bill Date:", bill_date)
print("Product Names:", product_names)
print("Quantities:", quantities)
print("Prices:", prices)
# Out:
# Bill Number: 502001009-001074
# Bill Date: 05/01/202312:51PM
# Product Names: ['GSTIN:36AACCA8432H1ZR', 'DMART KAVURI HILLS', 'KAVURI HILLS ROAO MADHAPUR', 'Ph0ne:040-23119921', 'No :502001009-001074', 'B1Ot：05/01/202312:51PM', 'HSN', 'NUTRAJ FLAX SE-200g', '150890 FREE001GROUNDN-11t', '55.00', 'GOLD OROP SUNFL-11t', '815.00', '148.00', '2)-005T6.00%,SGST-@6.00%', '18.00', 'PANTENE PR0-V-340ml', '319.00', '340540 PRIL LIME N VING-3g', '110.00', 'Items:6', '1613.00', '1110.48', '1166.00', '16.08', '0.96', '3', '2.72', '429.00', '61.44', '1613.00']
# Quantities: ['1', '1', '1', '11', '1', '2', '96', '3', '1490']
# Prices: ['55.00', '55.00', '163.00', '815.00', '148.00', '296.00', '18.00', '18.00', '319.00', '319.00', '110.00', '110.00', '1613.00', '1110.48', '27.76', '1166.00', '16.08', '0.96', '18.00', '363.56', '2.72', '32.72', '429.00', '61.44', '61.44', '1613.00']

# %%
#Invoice 11

text = """
D'Mart
AVENUE SUPERMARTS LTD
CIN：L51900MH2000PLC126473
GSTIN36AACCA8432H1ZR
FSSAI NO.:11512011001964
DMART HIMAYATHNAGAR
H.NO、3-6-288/4S5
OPP OIO MLA QURS
BESIDE TOYATA S
NROOM
HYUERGUOA BASHER GH ROAD
HYDERABAD
Q:J029
Phone:04
298560
TAX
8111：501801008-005005
S11Ot：28/01/2023(10:00A)
Vou.NoS138006-0008
ashier:SAP/138418
HSN
Par'ticulass
Qty/ng
N/Rate
Value
1)CG5T@2.50%,
@2.50%
090190 BRU GREEN LABE 500g
1
170.00
170.00
090230 BR00KE BOND 3R 500g
1
390.00
390.00
151590FREE00M RICE BR-11t
3
147.00
2)CE5T@ 9.00%,SUST @9.00%
441.00
190190 CADBURY BOURNV 200g
1
108.00
108.00
210690 MIR RAVA IDLI-1K
1
185.00
185.00
340119 PATANJALI SUPE-145g
7
9.00
63.00
340220 RIN L00ID DE-800m
148.00
592.00
3)CGST@6.00%,SGST@6.00%
42022272 CL0TH BAG
1
18.00
18.00
Items:8
Qty:
19
1967.00
GST Breakup Details
(Anount In)
GST
faxable
CGST
SGST
CESS
Total
IND
Anount
Angunt
1
953.34
23.83m
23.83
1001.00
2
803.38
72.31
72.31
948.00
3
0.96
0.96
13.00
16.08
97.10
97.10
1967.00
T:
1772.80
Anount Recelved From Customer
1967.00
Card Paymentf:
Saved Rs.381.00/-0nMRP """

# Extracting Bill Number
bill_number = re.search(r'8111：(.*?)\s', text).group(1)

# Extracting Bill Date
bill_date = re.search(r'S11Ot：(.*?)\(', text).group(1)

# Extracting Product Name, Quantity, and Price
table_data = re.findall(r'(\d+)\s*(.*?)\n(\d+)\n(\d+\.\d+)', text)
product_names = [data[1] for data in table_data]
quantities = [data[2] for data in table_data]
prices = [data[3] for data in table_data]

print("Bill Number:", bill_number)
print("Bill Date:", bill_date)
print("Product Names:", product_names)
print("Quantities:", quantities)
print("Prices:", prices)
# Out:
# Bill Number: 501801008-005005
# Bill Date: 28/01/2023
# Product Names: ['BRU GREEN LABE 500g', '090230 BR00KE BOND 3R 500g', '151590FREE00M RICE BR-11t', '190190 CADBURY BOURNV 200g', '210690 MIR RAVA IDLI-1K', '340119 PATANJALI SUPE-145g', 'CL0TH BAG', 'Qty:', '1001.00', '948.00']
# Quantities: ['1', '1', '3', '1', '1', '7', '1', '19', '2', '3']
# Prices: ['170.00', '390.00', '147.00', '108.00', '185.00', '9.00', '18.00', '1967.00', '803.38', '0.96']

# %%
#Invoice 12
import re

text = """
hrougr
origil
shall
food
3
DMart
ing
pi
FSSAI NO:11511007000195
Upperpally(Attapura)
400455
NEAR PI1LAR ND.198
UPPERPALLY
RAJENDRANAGARNER
HYDERAAA0 500048
Phone:040-29705890
TAX TNVOTCE
B111 NO:502512004-001747
Vou.No:S151004-0054
MOA/15156
HSN
Particalars
Quy/Kg
N/Rate
Value
1)CeST
SGST2.50%
G90922 AASHIRVAAD COR-200g
1
49.00
49:00
110100 AASHIKVAAD NHEA-1Kg
2
62.31
124,62
150790 FORTUNE S0YABEA-11t
1
148.00
148.00
151590 FORTUNE RICE BR-11t
1
147.00
147.00
2)CGST@6.00%,SGST@6.00%
420222 GREY COTTON SHOPPIN
1
29.00
29.00
3)CGST@9.00%,SGST@9.00%
190590 PARLEHIDE N S-100g
2
27.00
54.00
330499 NIVEA C0C0A N-400ml
2
259.50
519.00
330510 SUNSILK THICK-650ml
1
350.00
350,00
330610 CLOSEUP DEEP A-300g
1
121.00
121.00
340111MYS0RE SANDAL -125g
2
84.60
169.20
340540 EX0 ANT ROUND -700g
8
74.00
592.00
4)CGST@2.50%,SGST
T@2.50%
150890 FREE00M GROUNDN-11t
2
163.00
326.00
Items:12
Qty:
24
2628.82
GST Breakup Detalls
>（Amour:INR)
GST
Taxable
CGST
SGST
CESS
Tota
IND
Ariount
Anmount
1
446.30
11.16
11.16
468.62
2
25.90
1.55
1.55
29.00
3
1529.84
137.68
137.68
1805.20
4
310.48
7.76
7.76
326.00"""

# Extracting Bill Number
bill_number = re.search(r'B111 NO:(.*?)\n', text).group(1)

# Extracting Bill Date
bill_date_match = re.search(r'B111Dt :(.*?)\n', text)
bill_date = bill_date_match.group(1) if bill_date_match else ''

# Extracting Product Names, Quantities, and Prices
table_data = re.findall(r'(\d+)\s*(.*?)\n(\d+)\n(.*?)\n', text)
product_names = [data[1] for data in table_data]
quantities = [data[2] for data in table_data]
prices = [data[3] for data in table_data]

print("Bill Number:", bill_number)
print("Bill Date:", bill_date)
print("Product Names:", product_names)
print("Quantities:", quantities)
print("Prices:", prices)
# Out:
# Bill Number: 502512004-001747
# Bill Date:
# Product Names: ['Upperpally(Attapura)', 'AASHIRVAAD COR-200g', '110100 AASHIKVAAD NHEA-1Kg', '150790 FORTUNE S0YABEA-11t', '151590 FORTUNE RICE BR-11t', 'GREY COTTON SHOPPIN', 'PARLEHIDE N S-100g', '330499 NIVEA C0C0A N-400ml', '330510 SUNSILK THICK-650ml', '330610 CLOSEUP DEEP A-300g', '340111MYS0RE SANDAL -125g', '340540 EX0 ANT ROUND -700g', 'FREE00M GROUNDN-11t', 'Qty:', '468.62', '29.00', '1805.20']
# Quantities: ['400455', '1', '2', '1', '1', '1', '2', '2', '1', '1', '2', '8', '2', '24', '2', '3', '4']
# Prices: ['NEAR PI1LAR ND.198', '49.00', '62.31', '148.00', '147.00', '29.00', '27.00', '259.50', '350.00', '121.00', '84.60', '74.00', '163.00', '2628.82', '25.90', '1529.84', '310.48']

# %%
#Invoice 13
import re

text = """
turer.
befinal.
Nara
DMart
CIN：L51900MH2000PLC126473
GSTIN:36AACCA8432H1ZR
FSSAI NO:11511007000195
Upperpally(Attapura)
NEAR PILLAR NO.198
UPPERPALLY
RAJENDRANAGARNER
HYDERABAD 500048
phone:040-29705890
TAX INVOICE
PRI/151560
Vou.No:S151012-0086
N/Rate
Value
HSN
Particulars
18.00
72.
SGST0900
189.00
378.0
340111PEAR5
2
6
450.00
Items!
han
Qty:
GST Breakup Details
(Amount INR)
GST
Taxable
CGST
SGST
CESS
Total
IND
Amount
Amount
68.58
1.71
1.71
72.00
1
2
320.34
28.83
28.83
378.00
30.54
30.54
450.00
T:
388.92
Amount Recelved Fron Customer
450.00/
UPI Payment :
Saved fs.178 00/-0n Mpp
水
This Is computer generated invoice
ICICI BANK
M001635025DMARIUPP"""

# Extracting Bill Number
bill_number = re.search(r"PRI/(\d+)", text).group(1)

# Extracting Bill Date
bill_date = re.search(r"Vou.No:(.*?)\n", text).group(1)

# Extracting Product Names, Quantities, and Prices
table_data = re.findall(r"(\d+)\n(.*?)\n(\d+)\n(.*?)\n", text)
product_names = [data[1] for data in table_data]
quantities = [data[2] for data in table_data]
prices = [data[3] for data in table_data]

print("Bill Number:", bill_number)
print("Bill Date:", bill_date)
print("Product Names:", product_names)
print("Quantities:", quantities)
print("Prices:", prices)
# Out:
# Bill Number: 151560
# Bill Date: S151012-0086
# Product Names: ['340111PEAR5', '72.00']
# Quantities: ['2', '1']
# Prices: ['6', '2']

# %%
#Invoice 14

text = '''D'Mart
AVENUE SUPERMARTS LTD
CIN :L51900MH2000PLC126173
413483
GSTIN:36AACCA8432H1ZR
FSSAI ND.:13617014000881
DMART S D ROAD
112,SAROJINI DEVI ROAD
SECUNDERABAD
Ph0ne:040-27718041
TAX INVOICE
a111 No:501312019-003153
B111Dt:22/12/2022(5:12p
Vou.No:S142019-0089
Cashier :LI7/142501
HSN
Particulars
Qty/ng
N/Rate
Value
1)CGSY@2.50%,SGST2.50%
51311 MLF NIRMAL COCO-11t
1
225.00
225.0
2)CGST@6.00%,SGST @6.00%
210390 CHINGS RED CHI-200g
1
38.00
38.00
3) CGST @ 9.00%, SGST @9.00%
340119 PATANJALI SUPE-145g
6
9.00
54.00
Itens:3
Qty:
8
317.00
GST Breakup Details
> (Amount INR)
GST
Taxable
CGST
SGST
CESS
Total
IND
Amount
Amount
1
214.28
5.36
5.36
225.00
2
33.92
2.04
2.04
38.00
3
45.78
4.12
4.12
54.00
T:
293.96
11.52
11.
317.00
Amount Recefved
stomer
Lasr
400.00
Balance Paid
d In Casb
83.00
**Saved Ro
108.00/-0nMRP
2'''

# Extracting Bill Number
bill_number = re.search(r'No:(.*?)\s', text).group(1)

# Extracting Bill Date
bill_date = re.search(r'Dt:(.*?)\(', text).group(1)

# Extracting Product Name, Quantity, and Price
table_data = re.findall(r'(\d+)\s*(.*?)\n(\d+)\n(.*?)\n', text)
product_names = [data[1] for data in table_data]
quantities = [data[2] for data in table_data]
prices = [data[3] for data in table_data]

print("Bill Number:", bill_number)
print("Bill Date:", bill_date)
print("Product Names:", product_names)
print("Quantities:", quantities)
print("Prices:", prices)
# Out:
# Bill Number: 501312019-003153
# Bill Date: 22/12/2022
# Product Names: ['MH2000PLC126173', 'MLF NIRMAL COCO-11t', 'CHINGS RED CHI-200g', 'PATANJALI SUPE-145g', 'Qty:', '225.00', '38.00']
# Quantities: ['413483', '1', '1', '6', '8', '2', '3']
# Prices: ['GSTIN:36AACCA8432H1ZR', '225.00', '38.00', '9.00', '317.00', '33.92', '45.78']

# %%
#Invoice 15

text = '''FS6AI NO.:13617014000881
DMART S D ROAD
112,SAROJINI DEVI ROAD
SECUNDERABAD
phone:040.27718041
TAX INVOICE
B111Dt：19/12/20224-43
B111 No:581312023-019447
Vou.No$142023-0133
Cashier :REN/142402
Particulars
ty/ng
N/Rate
Value
HSN
11c6sf@9.00%,$681@9.00%
330499NIVEASKINMI-400ml
1
265.00
265.0
340540 VIM BAR 3UX200-600g
5
60.00
300.00
Items:2
Qty:
6
565.00
GST Breakup Details
(Amount INR)
GST
Taxable
COST
SGST
CESS
Total
IND
Anount
Amount
1
478.82
43.09
43.09
565.0
Akaunt Recaived Fron Custom
Card Payment
15.00/
Savof Rs.185.00
OFMRP**
Thia is computer generated Invoice.
Date/1ime :2022-12-19116:43:30
CARDNUM:XXXXKXXXKXXXB719
wipe
CARD TYPE:VISA
EXPIRY:XX/XX
PPR CODE :356098
RRN:000000016442'''

bill_number = re.search(r'B111\D*(\d{12}-\d+)', text)
bill_date = re.search(r'B111Dt\D*(\d{2}/\d{2}/\d{4})', text)
product_names = re.findall(r'\d+\n(\d+.*?)\n\d+\.\d{2}', text)
quantities = re.findall(r'\d+\n(\d+)\n\d+\.\d{2}', text)
prices = re.findall(r'\d+\n\d+\.\d{2}\n(.*?)\n\d+\n\d+\.\d{2}', text)

if bill_number:
    bill_number = bill_number.group(1)
else:
    bill_number = "Not found"

if bill_date:
    bill_date = bill_date.group(1)
else:
    bill_date = "Not found"

print("Bill Number:", bill_number)
print("Bill Date:", bill_date)

if product_names:
    print("Product Names:")
    for product in product_names:
        print(product)

if quantities:
    print("Quantities:")
    for quantity in quantities:
        print(quantity)

if prices:
    print("Prices:")
    for price in prices:
        print(price)
# Out:
# Bill Number: Not found
# Bill Date: 19/12/2022
# Product Names:
# 60.00
# 478.82

# %%
#invoice 16

text = '''BENGALURU
sRD14
agar
U
18
AVENUE SUPERMARTS LTD
CIN：L51900MH2000PLC126473
GSTIN:36AACCA8432H1ZR
FSSAI NO.:13617014000681
DMART S D ROAD
112SAROJINI DEVY RDAD
SECUNDERAZAD
Phone:040-2771
80
TAXINVOI
B111 No:501312019-00119
Bill
13/12/2022(3:41PM
Vou..
No：S142019-0056
Cashie
DES/142499
HSN
Particulars
Qty
N/Rate
Value
1)CGST@2.50%，SGST
2450%
090422 AASHIRVAAD CHI 500g
091030 AASHIRVAAD TUR 100g
155.00
155.00
1
21.00
21.00
2)CGST9.00%,SGST@9.00%
330499 NIVEA SKIN MI-400ml
1
265.00
265.00
330610 COLGATE DENTAL-100g
61.00
122.00
330810 PATANJALIREG -100g
2
50.00
100.00
340130 NIVEA MEN 0IL -100g
189.00
189.00
340540 VIM DISHWASH BA25g
5
9.30
46.50
380891HIT RE0C0CKR/400ml
195.00
195.00
B21210 GIL1ETEE GUAR&31R
108.00
108.00
3)CGSTG0.00%SGSTG000%
SALE ROUND OFT ACCOUNT
(-)0..
0.50
Items:9
Qty:
15
1201.00
GST Breakup D&tals
>(AmountINR)
GST
Taxable
CGST
SGST
CESS
Total
IND
Amount
Amount
1
167.62
4.19
4.19
176.00
2
869.06
78.22
78.22
1025.50
3
-0.50
-0.50
..
T:
1036.18
82.41
82.41
1201.00
..
Anount Received From Custamer
Cash :
1500.00/
Balance Pald In Cash
299.00'''

bill_number = re.search(r'B111\D*No:(\d{12}-\d+)', text)
bill_date = re.search(r'Bill\s+(\d{2}/\d{2}/\d{4})', text)
product_names = re.findall(r'\d+\D+(.+)\n\d{2,}', text)
quantities = re.findall(r'\n(\d+)\n\d{2,}', text)
prices = re.findall(r'\n\d+\n(.*?)\n\d{2,}', text)

bill_number = bill_number.group(1) if bill_number else 'Not found'
bill_date = bill_date.group(1) if bill_date else 'Not found'

print("Bill Number:", bill_number)
print("Bill Date:", bill_date)
print("Product Names:", product_names)
print("Quantities:", quantities)
print("Prices:", prices)
# Out:
# Bill Number: Not found
# Bill Date: 13/12/2022
# Product Names: ['U', 'D', '2771', 'l', '1)CGST@2.50%，SGST', '500g', '155.00', '1', '2)CGST9.00%,SGST@9.00%', '1', '265.00', '61.00', '2', '100.00', '100g', '189.00', '9.30', '380891HIT RE0C0CKR/400ml', '21210 GIL1ETEE GUAR&31R', '15', '1', '4.19', '2', '78.22', '1036.18', '82.41', ':', 'h']
# Quantities: ['1', '1', '2', '15', '1', '2']
# Prices: ['21.00', '265.00', '50.00', '9.30', '869.06']

# %%
import pandas as pd

# Create a list to store the invoice data
invoices = []

# Invoice 1
invoice_1 = {
    "Bill Number": "501802014-012959",
    "Bill Date": "03/02/2023",
    "Product Names": [],
    "Quantities": [],
    "Prices": []
}
invoices.append(invoice_1)

# Invoice 2
invoice_2 = {
    "Bill Number": "501803014-017065",
    "Bill Date": "06/03/2023",
    "Product Names": ['340220 RIN-800ml'],
    "Quantities": ['2'],
    "Prices": ['30.00']
}
invoices.append(invoice_2)

# Invoice 3
invoice_3 = {
    "Bill Number": "501904020-000797",
    "Bill Date": "04/04/2023",
    "Product Names": ['11lNo501904020-000797', '2.50%,SGST@2', '6.00%，SGSF@6.00%', '9.00%，5T@9.00%', '2.50%SGST电2.50%'],
    "Quantities": ['660', '107', '17', '230', '180', '125', '2672', '347', '238'],
    "Prices": ['177.00', '660.00', '107.00', '17.00', '230.00', '180.00', '125.00', '2672.00', '1900.00', '47.50', '15.18', '0.91', '347.46', '31.27', '238.10', '5.95', '2500.74', '85.83']
}
invoices.append(invoice_3)

# Invoice 4
invoice_4 = {
    "Bill Number": "502002018-002273",
    "Bill Date": "14/02/2023",
    "Product Names": ['2.50%,SGST@2.50%'],
    "Quantities": ['Not found'],
    "Prices": ['Not found']
}
invoices.append(invoice_4)

# Invoice 5
invoice_5 = {
    "Bill Number": "502502012-002653",
    "Bill Date": "13/02/20233:48P",
    "Product Names": ['SURF EXCEL MATI-21t', 'Qty'],
    "Quantities": ['2', '2'],
    "Prices": ['399.00', '8.00']
}
invoices.append(invoice_5)

# Invoice 6
invoice_6 = {
    "Bill Number": "502003017-004782",
    "Bill Date": "06/03/2023",
    "Product Names": ['FREE0DM GROUNDN-11t', '190410 KURMUR-500g'],
    "Quantities": ['150890', '00', '2', '1'],
    "Prices": ['5', '1', '6', '22.27']
}
invoices.append(invoice_6)

# Invoice 7
invoice_7 = {
    "Bill Number": "501801013-002605",
    "Bill Date": "16/01/2023",
    "Product Names": [],
    "Quantities": ['250100', '00', '110100', '330510', '00', '00', '1', '3', '3', '1', '5', '2', '10', '00', '00'],
    "Prices": ['3', '75.00', '258.00', '399.00', '26.00', '148.00', '163.00', '370.00', '30.00', '499.00', '190590', '160.00', '22', '150', '24']
}
invoices.append(invoice_7)

# Invoice 8
invoice_8 = {
    "Bill Number": "500301006-008452",
    "Bill Date": "07/01/2023(8:47P",
    "Product Names": ['TATA R0CK SAL-1Kg', 'BRITANNIA G00D-200g', '340540 EX0 ANT B ROUN-700g', '340540 EX0 ANT B RDUN-700g', 'ANURAG DEEPARAD-11t', 'Qty:', '90.00', '113.00', '370.00'],
    "Quantities": ['1', '2', '1', '1', '2', '8', '2', '3', '4'],
    "Prices": ['90.00', '45.00', '140.00', '140.00', '135.00', '843.00', '107.62', '313.56', '257.14']
}
invoices.append(invoice_8)

# Invoice 9
invoice_9 = {
    "Bill Number": "502001009-001341",
    "Bill Date": "06/01/2023",
    "Product Names": ['151590 FORFUNE RICE BR-1It', 'KISSAN MIX FRU-700g', 'PARLE HI0DE N S-100g', '340540 VIM POWER 100L-500g', 'Qty:', '417.00'],
    "Quantities": ['1', '2', '3', '5', '13', '2'],
    "Prices": ['147.00', '195.00', '27.00', '55.80', '1167.00', '348.22']
}
invoices.append(invoice_9)

# Invoice 10
invoice_10 = {
    "Bill Number": "502001009-001074",
    "Bill Date": "05/01/202312:51PM",
    "Product Names": ['GSTIN:36AACCA8432H1ZR', 'DMART KAVURI HILLS', 'KAVURI HILLS ROAO MADHAPUR', 'Ph0ne:040-23119921', 'No :502001009-001074', 'B1Ot：05/01/202312:51PM', 'HSN', 'NUTRAJ FLAX SE-200g', '150890 FREE001GROUNDN-11t', '55.00', 'GOLD OROP SUNFL-11t', '815.00', '148.00', '2)-005T6.00%,SGST-@6.00%', '18.00', 'PANTENE PR0-V-340ml', '319.00', '340540 PRIL LIME N VING-3g', '110.00', 'Items:6', '1613.00', '1110.48', '1166.00', '16.08', '0.96', '3', '2.72', '429.00', '61.44', '1613.00'],
    "Quantities": ['1', '1', '1', '11', '1', '2', '96', '3', '1490'],
    "Prices": ['55.00', '55.00', '163.00', '815.00', '148.00', '296.00', '18.00', '18.00', '319.00', '319.00', '110.00', '110.00', '1613.00', '1110.48', '27.76', '1166.00', '16.08', '0.96', '18.00', '363.56', '2.72', '32.72', '429.00', '61.44', '61.44', '1613.00']
}
invoices.append(invoice_10)

# Invoice 11
invoice_11 = {
    "Bill Number": "501801008-005005",
    "Bill Date": "28/01/2023",
    "Product Names": ['BRU GREEN LABE 500g', '090230 BR00KE BOND 3R 500g', '151590FREE00M RICE BR-11t', '190190 CADBURY BOURNV 200g', '210690 MIR RAVA IDLI-1K', '340119 PATANJALI SUPE-145g', 'CL0TH BAG'],
    "Quantities": ['1', '1', '3', '1', '1', '7', '1'],
    "Prices": ['170.00', '390.00', '147.00', '108.00', '185.00', '9.00', '18.00']
}
invoices.append(invoice_11)

# Invoice 12
invoice_12 = {
    "Bill Number": "502512004-001747",
    "Bill Date": "",
    "Product Names": ['Upperpally(Attapura)', 'AASHIRVAAD COR-200g', '110100 AASHIKVAAD NHEA-1Kg', '150790 FORTUNE S0YABEA-11t', '151590 FORTUNE RICE BR-11t', 'GREY COTTON SHOPPIN', 'PARLEHIDE N S-100g', '330499 NIVEA C0C0A N-400ml', '330510 SUNSILK THICK-650ml', '330610 CLOSEUP DEEP A-300g', '340111MYS0RE SANDAL -125g', '340540 EX0 ANT ROUND -700g', 'FREE00M GROUNDN-11t'],
    "Quantities": ['400455', '1', '2', '1', '1', '1', '2', '2', '1', '1', '2', '8', '2'],
    "Prices": ['NEAR PI1LAR ND.198', '49.00', '62.31', '148.00', '147.00', '29.00', '27.00', '259.50', '350.00', '121.00', '84.60', '74.00', '163.00']
}
invoices.append(invoice_12)

# Invoice 13
invoice_13 = {
    "Bill Number": "151560",
    "Bill Date": "S151012-0086",
    "Product Names": ['340111PEAR5'],
    "Quantities": ['2'],
    "Prices": ['6']
}
invoices.append(invoice_13)

# Invoice 14
invoice_14 = {
    "Bill Number": "501312019-003153",
    "Bill Date": "22/12/2022",
    "Product Names": ['MH2000PLC126173', 'MLF NIRMAL COCO-11t', 'CHINGS RED CHI-200g', 'PATANJALI SUPE-145g'],
    "Quantities": ['413483', '1', '1', '6'],
    "Prices": ['GSTIN:36AACCA8432H1ZR', '225.00', '38.00', '9.00']
}
invoices.append(invoice_14)

# Invoice 15
invoice_15 = {
    "Bill Number": "Not found",
    "Bill Date": "19/12/2022",
    "Product Names": ['60.00', '478.82'],
    "Quantities": [],
    "Prices": []
}
invoices.append(invoice_15)

# Invoice 16
invoice_16 = {
    "Bill Number": "Not found",
    "Bill Date": "13/12/2022",
    "Product Names": ['U', 'D', '2771', 'l', '1)CGST@2.50%，SGST', '500g', '155.00', '1', '2)CGST9.00%,SGST@9.00%', '1', '265.00', '61.00', '2', '100.00', '100g', '189.00', '9.30', '380891HIT RE0C0CKR/400ml', '21210 GIL1ETEE GUAR&31R', '15', '1', '4.19', '2', '78.22', '1036.18', '82.41', ':', 'h'],
    "Quantities": [],
    "Prices": []
}
invoices.append(invoice_16)

# Create a dataframe from the invoices list
df = pd.DataFrame(invoices)

# Print the dataframe
print(df)
# Out:
#          Bill Number          Bill Date  \
# 0   501802014-012959         03/02/2023
# 1   501803014-017065         06/03/2023
# 2   501904020-000797         04/04/2023
# 3   502002018-002273         14/02/2023
# 4   502502012-002653    13/02/20233:48P
# 5   502003017-004782         06/03/2023
# 6   501801013-002605         16/01/2023
# 7   500301006-008452   07/01/2023(8:47P
# 8   502001009-001341         06/01/2023
# 9   502001009-001074  05/01/202312:51PM
# 10  501801008-005005         28/01/2023
# 11  502512004-001747
# 12            151560       S151012-0086
# 13  501312019-003153         22/12/2022
# 14         Not found         19/12/2022
# 15         Not found         13/12/2022
#
#                                         Product Names  \
# 0                                                  []
# 1                                  [340220 RIN-800ml]
# 2   [11lNo501904020-000797, 2.50%,SGST@2, 6.00%，SG...
# 3                                  [2.50%,SGST@2.50%]
# ...

# %%
pip install pandas sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Create a DataFrame from the given data
data = {
    'Bill Number': [
        '501802014-012959', '501803014-017065', '501904020-000797',
        '502002018-002273', '502502012-002653', '502003017-004782',
        '501801013-002605', '500301006-008452', '502001009-001341',
        '502001009-001074', '501801008-005005', '502512004-001747',
        '151560', '501312019-003153', 'Not found', 'Not found'
    ],
    'Bill Date': [
        '03/02/2023', '06/03/2023', '04/04/2023', '14/02/2023',
        '13/02/20233:48P', '06/03/2023', '16/01/2023',
        '07/01/2023(8:47P', '06/01/2023', '05/01/202312:51PM',
        '28/01/2023', '', 'S151012-0086', '22/12/2022', '19/12/2022',
        '13/12/2022'
    ],
    'Product Names': [
        [], ['340220 RIN-800ml'],
        ['11lNo501904020-000797', '2.50%,SGST@2', '6.00%，SG'],
        ['2.50%,SGST@2.50%'], ['SURF EXCEL MATI-21t, Qty'],
        ['FREE0DM GROUNDN-11t', '190410 KURMUR-500g'], [],
        ['TATA R0CK SAL-1Kg', 'BRITANNIA G00D-200g', '34054'],
        [
            '151590 FORFUNE RICE BR-1It', 'KISSAN MIX FRU-70',
            'GSTIN:36AACCA8432H1ZR', 'DMART KAVURI HILLS', 'KA'
        ],
        [
            'BRU GREEN LABE 500g', '090230 BR00KE BOND 3R 50',
            'Upperpally(Attapura)', 'AASHIRVAAD COR-200g',
            '11'
        ],
        [], ['340111PEAR5'],
        [
            'MH2000PLC126173', 'MLF NIRMAL COCO-11t',
            'CHINGS'
        ],
        ['60.00, 478.82'],
        [
            'U', 'D', '2771', 'l', '1)CGST@2.50%，SGST', '500g',
            '155.0'
        ],
    ],
    'Quantities': [
        [], ['2'],
        [
            '660', '107', '17', '230', '180', '125', '2672', '347',
            '238'
        ],
        ['Not found'], ['2', '2'],
        ['150890', '00', '2', '1'],
        [
            '250100', '00', '110100', '330510', '00', '00', '1',
            '3', '3', '...'
        ],
        ['1', '2', '1', '1', '2', '8', '2', '3', '4'],
        ['1', '2', '3', '5', '13', '2'],
        ['1', '1', '1', '11', '1', '2', '96', '3', '1490'],
        ['1', '1', '3', '1', '1', '7', '1'],
        [
            '400455', '1', '2', '1', '1', '1', '2', '2', '1', '1',
            '2', '8', '2'
        ],
        ['2'], ['413483', '1', '1', '6'], [],
        [],
    ],
    'Prices': [
        [], ['30.00'],
        [
            '177.00', '660.00', '107.00', '17.00', '230.00',
            '180.00', '...'
        ],
        ['Not found'], ['399.00', '8.00'],
        ['5', '1', '6', '22.27'],
        [
            '3', '75.00', '258.00', '399.00', '26.00',
            '148.00', '163.00', '...'
        ],
        [
            '90.00', '45.00', '140.00', '140.00',
            '135.00', '843.00', '...', '1', '55.00', '55.00'
        ],
        [
            '147.00', '195.00', '27.00', '55.80', '1167.00',
            '348.22'
        ],
        [
            '55.00', '55.00', '163.00', '815.00',
            '148.00', '296.00', '...'
        ],
        [
            '170.00', '390.00', '147.00', '108.00', '185.00',
            '9.00', '...', 'NEAR PI1LAR ND.198', '49.00'
        ],
        ['6'],
        ['GSTIN:36AACCA8432H1ZR', '225.00', '38.00', '9.00'],
        [],
        [],
    ]
}

# Ensure all arrays have the same length
max_length = max(len(data['Bill Number']), len(data['Bill Date']),
                 len(data['Product Names']), len(data['Quantities']),
                 len(data['Prices']))

# Pad arrays with empty strings to match the maximum length
data['Bill Number'] += [''] * (max_length - len(data['Bill Number']))
data['Bill Date'] += [''] * (max_length - len(data['Bill Date']))
data['Product Names'] += [[]] * (max_length - len(data['Product Names']))
data['Quantities'] += [[]] * (max_length - len(data['Quantities']))
data['Prices'] += [[]] * (max_length - len(data['Prices']))

# Create a DataFrame from the updated data
df = pd.DataFrame(data)

# Convert the DataFrame to CSV
df.to_csv('C:/Users/Lenovo/Desktop/Project_111/bill_data.csv', index=False)

# %%
pip install paddlepaddle paddleocr streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -addlepaddle (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -addlepaddle (c:\users\lenovo\anaconda3\lib\site-packages)

# %%
import streamlit as st
import paddleocr
import re
import pandas as pd
from paddleocr import PaddleOCR, draw_ocr
import cv2
import numpy as np
ocr = PaddleOCR()
import os
from PIL import Image


def main():
    
    logo_image = Image.open(r'C:/Users/Lenovo/Desktop/Project_111/bill_data.csv')
    st.image(logo_image, width=400)

    st.title("Welcome To V-LO's Invoice Processing Tool")

    # Add an "Upload Images" section
    st.header("Upload your Invoice")
    uploaded_files = st.file_uploader("Choose a folder of images", type="jpeg", accept_multiple_files=True)

    if st.button("Process Invoice"):
        if uploaded_files:
            # Create a list to store the results
            results = []

            # Iterate over the uploaded files and process each image
            for file in uploaded_files:
                # Read the image using OpenCV
                image = cv2.imdecode(np.fromstring(file.read(), np.uint8), cv2.IMREAD_COLOR)

                # Perform OCR on the image using PaddleOCR
                result = ocr.ocr(image)

                # Store the result in the list
                results.append((file.name, result))

            # Process the stored results
            text = []
            for filename, result in results:
                #st.subheader(f"Text in {filename}:")
                for line in result:
                    for word in line:
                       # st.write(word[1][0])
                        text.append(word[1][0])
                    #st.write()
               # st.write()

            # Create a DataFrame to store the extracted information
            df1 = pd.DataFrame(columns=['Bill_Date', 'Bill_No', 'Bill_Product', 'Bill_Quantity', 'Unit_Price'])
            bill_no = None
            bill_date = None

            for i in range(len(text)):
                item = text[i]

                # Match bill number
                match_bill_no = re.search(r"\d{9}-\d{1,6}", item)
                if match_bill_no:
                    bill_no = match_bill_no.group()
                    #st.write("Bill Number:", bill_no)

                # Match bill date
                match_bill_date = re.search(r"\d{2}/\d{2}/\d{4}", item)
                if match_bill_date:
                    bill_date = match_bill_date.group()
                    #st.write("Bill Date:", bill_date)

                # Match product name
                match_product = re.search(
                    r"\s[A-Z]+\s[A-Z0-9]+\s[A-Z]+-\d[a-zA-Z]+|\s[A-Z]+\s[A-Z]+\s[A-Z]+-\d[a-zA-Z]+|[a-zA-Z]+[]\s\d+-[a-zA-Z]+\d[a-z]+|[a-aA-Z]+\s[a-zA-z]+\s+[a-zA-z]+\s\d+[a-zA-z]|[A-Z]+-\d+[a-zA-Z]|[A-z]+\s[A-Z]+-[a-zA-Z]+",
                    item)
                if match_product:
                    product_name = match_product.group()
                   # st.write("Product Name:", product_name)

                    # Initialize quantity and price
                    quantity = None
                    price = None

                    # Check the next row for quantity (single/double-digit integer)
                    if i + 1 < len(text):
                        next_item = text[i + 1]
                        match_quantity = re.search(r"\b(\d{1,2})\b", next_item)

                        if match_quantity:
                            quantity = int(match_quantity.group())

                        # Check the next three rows for the price (first float value)
                        for j in range(i + 1, i + 4):
                            if j < len(text):
                                next_item = text[j]
                                match_price = re.search(r"\b(\d+\.\d+)\b", next_item)

                                if match_price:
                                    price = float(match_price.group())
                                    break  # Stop searching for price after the first match

                    # Set default quantity as 1 if no value is found
                    if quantity is None:
                        quantity = 0

                    # Add the data to the DataFrame
                    df1.loc[len(df1)] = [bill_date, bill_no, product_name, quantity, price]

            # Display the extracted information in a table
            st.subheader("Extracted Information:")
            st.write(df1)
        else:
            st.warning("Please upload a folder of images.")

if __name__ == "__main__":
    # Load PaddleOCR
    ocr = PaddleOCR()

    # Run the Streamlit app
    main()
# Out:
# [2023/07/03 19:33:08] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\det\\ch\\ch_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\Lenovo/.paddleocr/whl\\rec\\ch\\ch_PP-OCRv3_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_text_length=25
# ...
